# %%
# libraries
import requests
import gzip
from io import BytesIO
import os

import numpy as np
import pandas as pd
from pandas_dq import dq_report

from sklearn.linear_model import LinearRegression

import folium
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from folium.plugins import TimestampedGeoJson

# %% [markdown]
# le fichier clean est désormais dispo sur S3 : https://jedha-final-project-jrat.s3.amazonaws.com/datameteo_france_1950-2022_clean_04.csv

# %%
url = "https://jedha-final-project-jrat.s3.amazonaws.com/datameteo_france_1950-2022_clean_04.csv"
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (340387, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340387 entries, 0 to 340386
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   NUM_POSTE                      340387 non-null  int64
#  1   NOM_USUEL                      340387 non-null  object
#  2   LAT                            340387 non-null  float64
#  3   LON                            340387 non-null  float64
#  4   ALTI                           340387 non-null  int64
#  5   AAAAMM                         340387 non-null  object
#  6   Year                           340387 non-null  int64
#  7   Month                          340387 non-null  int64
#  8   precip_cumul_mensu             327731 non-null  float64
#  9   temp_mean_mensu                335882 non-null  float64
#  10  temp_max_mensu                 335883 non-null  float64
#  11  temp_min_mensu                 335953 non-null  float64
#  12  NBJGELEE                       335890 non-null  float64
#  13  humi_min_mensu                 303957 non-null  float64
#  14  humi_max_mensu                 304191 non-null  float64
#  15  humi_moy_mensu                 285218 non-null  float64
#  16  vent_speed_inst_moy_mensu      340387 non-null  float64
#  17  vent_speed_inst_max_mensu      326437 non-null  float64
#  18  vent_dir_inst                  307836 non-null  float64
#  19  vent_nbjour_inst_speedsup10ms  326442 non-null  float64
#  20  vent_speed_10mn_max_mensu      274910 non-null  float64
#  21  vent_dir_10mn                  271602 non-null  float64
#  22  vent_nbjour_10mn_speedsup10ms  274910 non-null  float64
#  23  departement_num                340387 non-null  int64
#  24  departement_name               340387 non-null  object
#  25  region                         340387 non-null  object
#  26  is_authorized                  340387 non-null  bool
# dtypes: bool(1), float64(17), int64(5), object(4)
# memory usage: 67.8+ MB

# %% [markdown]
# - Aucune valeur manquante sur notre future target "vent_speed_inst_moy_mensu"
# - Pour le moment nous allons travailler sur la position de la station et la vitesse du vent moyenne mensuelle, sans prendre en compte le reste des éléménts

# %% [markdown]
# OBJECTIF 1 : déterminer si la force du vent augmente ou pas

# %% [markdown]
# - statistiques gobales nationales

# %%
# en France : moyenne des vents par mois depuis 1950 
df_monthly = df.groupby("AAAAMM")["vent_speed_inst_moy_mensu"].mean().reset_index()

fig = px.line(df_monthly, x="AAAAMM", y="vent_speed_inst_moy_mensu", title="Vitesse moyenne du vent en France depuis 1950")
fig.show()

# %% [markdown]
# Globalement il y a moins de vent en France. Mais il semblerait que la tendance soit à une augmentation depuis 2010. vérifions en affichant les chiffres et sur une période base de 7 ans

# %%
# Tableau avec les moyennes mensuelles calculés
df_monthly
# Out:
#        AAAAMM    vent_speed_inst_moy_mensu
# 0    1950-01-01          12.921101
# 1    1950-02-01          21.266667
# 2    1950-03-01          13.551786
# 3    1950-04-01          18.109910
# 4    1950-05-01          12.629204
# ..          ...                        ...
# 871  2022-08-01          10.055252
# 872  2022-09-01          10.688540
# 873  2022-10-01          10.449250
# 874  2022-11-01          12.465894
# 875  2022-12-01          11.828728
#
# [876 rows x 2 columns]

# %%
# AAAAMM en datetime
df_monthly["AAAAMM"] = pd.to_datetime(df_monthly["AAAAMM"], format='%Y-%m-%d', errors='coerce')

# périodes d'intérêt
periods = [
    (1956, 1963),
    (1963, 1970),
    (1971, 1978),
    (1979, 1985),
    (1986, 1992),
    (1993, 2000),
    (2001, 2008),
    (2009, 2015),
    (2016, 2022)
]

# vitesse moyenne du vent pour chaque période et stockage
mean_wind_speeds = []
for start_year, end_year in periods:
    df_period = df_monthly[(df_monthly["AAAAMM"].dt.year >= start_year) & (df_monthly["AAAAMM"].dt.year <= end_year)]
    mean_wind_speed = df_period['vent_speed_inst_moy_mensu'].mean()
    mean_wind_speeds.append((start_year, end_year, mean_wind_speed))
    print(f"Vitesse moyenne du vent entre {start_year} et {end_year}: {mean_wind_speed}")

# graphique
fig = px.line()

# courbes pour chaque période
for start_year, end_year in periods:
    df_period = df_monthly[(df_monthly["AAAAMM"].dt.year >= start_year) & (df_monthly["AAAAMM"].dt.year <= end_year)]
    fig.add_scatter(x=df_period['AAAAMM'], y=df_period['vent_speed_inst_moy_mensu'], mode='lines', name=f'{start_year}-{end_year}')

# annotations pour les vitesses moyennes
annotations = []
for (start_year, end_year, mean_wind_speed) in mean_wind_speeds:
    df_period = df_monthly[(df_monthly["AAAAMM"].dt.year >= start_year) & (df_monthly["AAAAMM"].dt.year <= end_year)]
    max_date = df_period['AAAAMM'].max()
    max_speed = df_period['vent_speed_inst_moy_mensu'].max()
    annotations.append(dict(
        x=max_date,
        y=max_speed,
        xref="x",
        yref="y",
        text=f"Mean: {mean_wind_speed:.2f}",
        showarrow=False,
        xanchor='right',  # Décalage horizontal vers la gauche
        yanchor='auto',
        xshift=-30
    ))

# légende et annotations
fig.update_layout(title='Vitesse moyenne du vent par période de 7 ans',
                  xaxis_title='Année',
                  yaxis_title='Vitesse moyenne du vent (km/h)',
                  annotations=annotations)

fig.show()
# Out:
# Vitesse moyenne du vent entre 1956 et 1963: 14.676349031903813
# Vitesse moyenne du vent entre 1963 et 1970: 15.050576887685216
# Vitesse moyenne du vent entre 1971 et 1978: 14.681297899151224
# Vitesse moyenne du vent entre 1979 et 1985: 14.921481756236986
# Vitesse moyenne du vent entre 1986 et 1992: 12.80727255797555
# Vitesse moyenne du vent entre 1993 et 2000: 11.496474061836382
# Vitesse moyenne du vent entre 2001 et 2008: 11.369316671825331
# Vitesse moyenne du vent entre 2009 et 2015: 11.448273793885734
# Vitesse moyenne du vent entre 2016 et 2022: 11.654824110893795

# %% [markdown]
# Une augmentation du vent semble se dégager en France. Mais une force moyenne de 11.65 km/h est insufisant pour faire tourner une éolienne.
# Vérifier la périodicité ou la force serait supérieur 14km/h (force minimale)

# %%
# périodes d'intérêt
periods = [
     (1956, 1963),
    (1963, 1970),
    (1971, 1978),
    (1979, 1985),
    (1986, 1992),
    (1993, 2000),
    (2001, 2008),
    (2009, 2015),
    (2016, 2022)
]

counts = {}

# boucle pour chaque période
for start, end in periods:
    period_df = df_monthly[(df_monthly["AAAAMM"].dt.year >= start) & (df_monthly["AAAAMM"].dt.year <= end)]
    count = period_df[period_df["vent_speed_inst_moy_mensu"] > 14].shape[0]
    counts[f"{start}-{end}"] = count

# résultats
print("Nombre de mois où la vitesse moyenne du vent est supérieure à 14 km/h:")
for period, count in counts.items():
    print(f"{period}: {count}")
# Out:
# Nombre de mois où la vitesse moyenne du vent est supérieure à 14 km/h:
# 1956-1963: 54
# 1963-1970: 60
# 1971-1978: 55
# 1979-1985: 50
# 1986-1992: 17
# 1993-2000: 10
# 2001-2008: 3
# 2009-2015: 6
# 2016-2022: 7

# %% [markdown]
# Résultat faible, mais au national cela n'est pas très parlant. Examinons les zones de manières régionales

# %%
# df vent par date et region
df_date_region = df.groupby(["AAAAMM", "region"])["vent_speed_inst_moy_mensu"].mean().reset_index()

# %%
# AAAAMM to datetime
df_date_region["AAAAMM"] = pd.to_datetime(df_date_region["AAAAMM"], format='%Y-%m-%d', errors='coerce')

# périodes d'intérêt
periods = [
    (1956, 1963),
    (1963, 1970),
    (1971, 1978),
    (1979, 1985),
    (1986, 1992),
    (1993, 2000),
    (2001, 2008),
    (2009, 2015),
    (2016, 2022)
]

# mean wind speed par periode et region / store
mean_wind_speeds = []
for start_year, end_year in periods:
    for region in df_date_region['region'].unique():
        df_period_region = df_date_region[(df_date_region["AAAAMM"].dt.year >= start_year) & 
                                          (df_date_region["AAAAMM"].dt.year <= end_year) & 
                                          (df_date_region['region'] == region)]
        mean_wind_speed = df_period_region['vent_speed_inst_moy_mensu'].mean()
        mean_wind_speeds.append((start_year, end_year, region, mean_wind_speed))
        print(f"Vitesse moyenne du vent entre {start_year} et {end_year} pour la région {region}: {mean_wind_speed}")

# graphique
for region in df_date_region['region'].unique():
    fig = px.line()
    for start_year, end_year in periods:
        df_period_region = df_date_region[(df_date_region["AAAAMM"].dt.year >= start_year) & 
                                          (df_date_region["AAAAMM"].dt.year <= end_year) & 
                                          (df_date_region['region'] == region)]
        fig.add_scatter(x=df_period_region['AAAAMM'], y=df_period_region['vent_speed_inst_moy_mensu'], mode='lines', name=f'{start_year}-{end_year}')
    
    fig.update_layout(title=f'Vitesse moyenne du vent par période pour la région {region}',
                      xaxis_title='Année',
                      yaxis_title='Vitesse moyenne du vent (km/h)')
    fig.show()
# Out:
# Vitesse moyenne du vent entre 1956 et 1963 pour la région AUVERGNE RHONE ALPES: 11.338715277777778
# Vitesse moyenne du vent entre 1956 et 1963 pour la région BOURGOGNE FRANCHE COMTE: 11.238958333333334
# Vitesse moyenne du vent entre 1956 et 1963 pour la région BRETAGNE: 19.635682199744696
# Vitesse moyenne du vent entre 1956 et 1963 pour la région CENTRE VAL DE LOIRE: 13.15459449404762
# Vitesse moyenne du vent entre 1956 et 1963 pour la région CORSE: 16.418536706349204
# Vitesse moyenne du vent entre 1956 et 1963 pour la région GRAND EST: 11.112465277777778
# Vitesse moyenne du vent entre 1956 et 1963 pour la région HAUTS DE FRANCE: 16.783530092592596
# Vitesse moyenne du vent entre 1956 et 1963 pour la région ILE DE FRANCE: 14.32051711309524
# Vitesse moyenne du vent entre 1956 et 1963 pour la région NORMANDIE: 17.661197916666666
# Vitesse moyenne du vent entre 1956 et 1963 pour la région NOUVELLE AQUITAINE: 12.367332303113551
# Vitesse moyenne du vent entre 1956 et 1963 pour la région OCCITANIE: 15.637129103535353
# Vitesse moyenne du vent entre 1956 et 1963 pour la région PAYS DE LA LOIRE: 15.401041666666666
# Vitesse moyenne du vent entre 1956 et 1963 pour la région PROVENCE ALPES COTE D'AZUR: 16.806800118284496
# Vitesse moyenne du vent entre 1963 et 1970 pour la région AUVERGNE RHONE ALPES: 11.442988175019423
# Vitesse moyenne du vent entre 1963 et 1970 pour la région BOURGOGNE FRANCHE COMTE: 11.402320075757578
# Vitesse moyenne du vent entre 1963 et 1970 pour la région BRETAGNE: 19.894132863664115
# Vitesse moyenne du vent entre 1963 et 1970 pour la région CENTRE VAL DE LOIRE: 13.136346726190476
# Vitesse moyenne du vent entre 1963 et 1970 pour la région CORSE: 18.815445188492063
# Vitesse moyenne du vent entre 1963 et 1970 pour la région GRAND EST: 11.456988636363635
# Vitesse moyenne du vent entre 1963 et 1970 pour la région HAUTS DE FRANCE: 16.704062500000003
# Vitesse moyenne du vent entre 1963 et 1970 pour la région ILE DE FRANCE: 14.111049107142856
# Vitesse moyenne du vent entre 1963 et 1970 pour la région NORMANDIE: 17.39773726851852
# Vitesse moyenne du vent entre 1963 et 1970 pour la région NOUVELLE AQUITAINE: 12.322678571428574
# Vitesse moyenne du vent entre 1963 et 1970 pour la région OCCITANIE: 17.266532165750917
# Vitesse moyenne du vent entre 1963 et 1970 pour la région PAYS DE LA LOIRE: 14.70434027777778
# Vitesse moyenne du vent entre 1963 et 1970 pour la région PROVENCE ALPES COTE D'AZUR: 16.827579876340156
# Vitesse moyenne du vent entre 1971 et 1978 pour la région AUVERGNE RHONE ALPES: 11.309455735236986
# Vitesse moyenne du vent entre 1971 et 1978 pour la région BOURGOGNE FRANCHE COMTE: 10.893276515151515
# Vitesse moyenne du vent entre 1971 et 1978 pour la région BRETAGNE: 19.67358287545788
# Vitesse moyenne du vent entre 1971 et 1978 pour la région CENTRE VAL DE LOIRE: 13.011396329365079
# Vitesse moyenne du vent entre 1971 et 1978 pour la région CORSE: 16.95642361111111
# Vitesse moyenne du vent entre 1971 et 1978 pour la région GRAND EST: 11.636271367521369
# Vitesse moyenne du vent entre 1971 et 1978 pour la région HAUTS DE FRANCE: 16.976180555555555
# Vitesse moyenne du vent entre 1971 et 1978 pour la région ILE DE FRANCE: 13.746432705026455
# Vitesse moyenne du vent entre 1971 et 1978 pour la région NORMANDIE: 17.52650462962963
# Vitesse moyenne du vent entre 1971 et 1978 pour la région NOUVELLE AQUITAINE: 11.823081597222222
# Vitesse moyenne du vent entre 1971 et 1978 pour la région OCCITANIE: 17.586309523809522
# Vitesse moyenne du vent entre 1971 et 1978 pour la région PAYS DE LA LOIRE: 14.444722222222223
# Vitesse moyenne du vent entre 1971 et 1978 pour la région PROVENCE ALPES COTE D'AZUR: 15.346513158410682
# Vitesse moyenne du vent entre 1979 et 1985 pour la région AUVERGNE RHONE ALPES: 10.75292735042735
# Vitesse moyenne du vent entre 1979 et 1985 pour la région BOURGOGNE FRANCHE COMTE: 10.90108225108225
# Vitesse moyenne du vent entre 1979 et 1985 pour la région BRETAGNE: 19.9569610761289
# Vitesse moyenne du vent entre 1979 et 1985 pour la région CENTRE VAL DE LOIRE: 14.051955782312922
# Vitesse moyenne du vent entre 1979 et 1985 pour la région CORSE: 17.15304232804233
# Vitesse moyenne du vent entre 1979 et 1985 pour la région GRAND EST: 12.47129120879121
# Vitesse moyenne du vent entre 1979 et 1985 pour la région HAUTS DE FRANCE: 17.06843584656085
# Vitesse moyenne du vent entre 1979 et 1985 pour la région ILE DE FRANCE: 13.891560846560846
# Vitesse moyenne du vent entre 1979 et 1985 pour la région NORMANDIE: 18.017267917267915
# Vitesse moyenne du vent entre 1979 et 1985 pour la région NOUVELLE AQUITAINE: 12.09974092902922
# Vitesse moyenne du vent entre 1979 et 1985 pour la région OCCITANIE: 17.149728407829503
# Vitesse moyenne du vent entre 1979 et 1985 pour la région PAYS DE LA LOIRE: 14.225056689342404
# Vitesse moyenne du vent entre 1979 et 1985 pour la région PROVENCE ALPES COTE D'AZUR: 16.108099206349202
# Vitesse moyenne du vent entre 1986 et 1992 pour la région AUVERGNE RHONE ALPES: 9.638899658385757
# Vitesse moyenne du vent entre 1986 et 1992 pour la région BOURGOGNE FRANCHE COMTE: 9.632056575362876
# Vitesse moyenne du vent entre 1986 et 1992 pour la région BRETAGNE: 16.59545957461507
# Vitesse moyenne du vent entre 1986 et 1992 pour la région CENTRE VAL DE LOIRE: 13.45941468253968
# Vitesse moyenne du vent entre 1986 et 1992 pour la région CORSE: 15.243625113312614
# Vitesse moyenne du vent entre 1986 et 1992 pour la région GRAND EST: 10.844971656961436
# Vitesse moyenne du vent entre 1986 et 1992 pour la région HAUTS DE FRANCE: 15.432665378542136
# Vitesse moyenne du vent entre 1986 et 1992 pour la région ILE DE FRANCE: 13.486012763396511
# Vitesse moyenne du vent entre 1986 et 1992 pour la région NORMANDIE: 19.347652208902204
# Vitesse moyenne du vent entre 1986 et 1992 pour la région NOUVELLE AQUITAINE: 10.355396059826106
# Vitesse moyenne du vent entre 1986 et 1992 pour la région OCCITANIE: 12.521485659746682
# Vitesse moyenne du vent entre 1986 et 1992 pour la région PAYS DE LA LOIRE: 14.276284013605443
# Vitesse moyenne du vent entre 1986 et 1992 pour la région PROVENCE ALPES COTE D'AZUR: 12.7122737442557
# Vitesse moyenne du vent entre 1993 et 2000 pour la région AUVERGNE RHONE ALPES: 8.802930302199636
# Vitesse moyenne du vent entre 1993 et 2000 pour la région BOURGOGNE FRANCHE COMTE: 8.882614386482727
# Vitesse moyenne du vent entre 1993 et 2000 pour la région BRETAGNE: 15.452232503534523
# Vitesse moyenne du vent entre 1993 et 2000 pour la région CENTRE VAL DE LOIRE: 12.279956496050247
# Vitesse moyenne du vent entre 1993 et 2000 pour la région CORSE: 13.414708114239849
# Vitesse moyenne du vent entre 1993 et 2000 pour la région GRAND EST: 10.090076507787323
# Vitesse moyenne du vent entre 1993 et 2000 pour la région HAUTS DE FRANCE: 14.143047001096583
# Vitesse moyenne du vent entre 1993 et 2000 pour la région ILE DE FRANCE: 12.723987552059212
# Vitesse moyenne du vent entre 1993 et 2000 pour la région NORMANDIE: 16.078189250552047
# Vitesse moyenne du vent entre 1993 et 2000 pour la région NOUVELLE AQUITAINE: 10.634011983221772
# Vitesse moyenne du vent entre 1993 et 2000 pour la région OCCITANIE: 12.194565420024952
# Vitesse moyenne du vent entre 1993 et 2000 pour la région PAYS DE LA LOIRE: 13.705246138477321
# Vitesse moyenne du vent entre 1993 et 2000 pour la région PROVENCE ALPES COTE D'AZUR: 10.66376171281644
# Vitesse moyenne du vent entre 2001 et 2008 pour la région AUVERGNE RHONE ALPES: 8.944317619298205
# Vitesse moyenne du vent entre 2001 et 2008 pour la région BOURGOGNE FRANCHE COMTE: 9.13341552978182
# Vitesse moyenne du vent entre 2001 et 2008 pour la région BRETAGNE: 15.332417547459514
# Vitesse moyenne du vent entre 2001 et 2008 pour la région CENTRE VAL DE LOIRE: 11.646751379165105
# Vitesse moyenne du vent entre 2001 et 2008 pour la région CORSE: 12.64961209447229
# Vitesse moyenne du vent entre 2001 et 2008 pour la région GRAND EST: 10.78655423457698
# Vitesse moyenne du vent entre 2001 et 2008 pour la région HAUTS DE FRANCE: 14.494514054240256
# Vitesse moyenne du vent entre 2001 et 2008 pour la région ILE DE FRANCE: 12.196367381292694
# Vitesse moyenne du vent entre 2001 et 2008 pour la région NORMANDIE: 15.006773323873205
# Vitesse moyenne du vent entre 2001 et 2008 pour la région NOUVELLE AQUITAINE: 10.799622213603707
# Vitesse moyenne du vent entre 2001 et 2008 pour la région OCCITANIE: 12.189519697908379
# Vitesse moyenne du vent entre 2001 et 2008 pour la région PAYS DE LA LOIRE: 13.463804857708672
# Vitesse moyenne du vent entre 2001 et 2008 pour la région PROVENCE ALPES COTE D'AZUR: 10.342946772689562
# Vitesse moyenne du vent entre 2009 et 2015 pour la région AUVERGNE RHONE ALPES: 9.483797503471216
# Vitesse moyenne du vent entre 2009 et 2015 pour la région BOURGOGNE FRANCHE COMTE: 9.022989514871174
# Vitesse moyenne du vent entre 2009 et 2015 pour la région BRETAGNE: 15.527001844798534
# Vitesse moyenne du vent entre 2009 et 2015 pour la région CENTRE VAL DE LOIRE: 10.634704973157355
# Vitesse moyenne du vent entre 2009 et 2015 pour la région CORSE: 12.198761988165199
# Vitesse moyenne du vent entre 2009 et 2015 pour la région GRAND EST: 10.656154248647468
# Vitesse moyenne du vent entre 2009 et 2015 pour la région HAUTS DE FRANCE: 14.520004831478047
# Vitesse moyenne du vent entre 2009 et 2015 pour la région ILE DE FRANCE: 11.354912362932291
# Vitesse moyenne du vent entre 2009 et 2015 pour la région NORMANDIE: 14.835382442016396
# Vitesse moyenne du vent entre 2009 et 2015 pour la région NOUVELLE AQUITAINE: 10.40170607531735
# Vitesse moyenne du vent entre 2009 et 2015 pour la région OCCITANIE: 12.472360129707052
# Vitesse moyenne du vent entre 2009 et 2015 pour la région PAYS DE LA LOIRE: 12.882450304515162
# Vitesse moyenne du vent entre 2009 et 2015 pour la région PROVENCE ALPES COTE D'AZUR: 10.867708674400923
# Vitesse moyenne du vent entre 2016 et 2022 pour la région AUVERGNE RHONE ALPES: 9.682034346688077
# Vitesse moyenne du vent entre 2016 et 2022 pour la région BOURGOGNE FRANCHE COMTE: 9.708294493694279
# Vitesse moyenne du vent entre 2016 et 2022 pour la région BRETAGNE: 15.798083237496357
# Vitesse moyenne du vent entre 2016 et 2022 pour la région CENTRE VAL DE LOIRE: 10.907909737969263
# Vitesse moyenne du vent entre 2016 et 2022 pour la région CORSE: 12.919171595615353
# Vitesse moyenne du vent entre 2016 et 2022 pour la région GRAND EST: 11.290179048207607
# Vitesse moyenne du vent entre 2016 et 2022 pour la région HAUTS DE FRANCE: 14.409243697478994
# Vitesse moyenne du vent entre 2016 et 2022 pour la région ILE DE FRANCE: 11.6617217707241
# Vitesse moyenne du vent entre 2016 et 2022 pour la région NORMANDIE: 15.507499914141198
# Vitesse moyenne du vent entre 2016 et 2022 pour la région NOUVELLE AQUITAINE: 10.41876732423918
# Vitesse moyenne du vent entre 2016 et 2022 pour la région OCCITANIE: 12.110636958050119
# Vitesse moyenne du vent entre 2016 et 2022 pour la région PAYS DE LA LOIRE: 12.700975422427037
# Vitesse moyenne du vent entre 2016 et 2022 pour la région PROVENCE ALPES COTE D'AZUR: 10.695834624793367

# %%
# df avec les données de vent_speed_inst_moy_mensu par période et region
df_period_region = pd.DataFrame(mean_wind_speeds, columns=["start_year", "end_year", "region", "mean_wind_speed"])
df_period_region.sort_values(by=["region", "start_year", "end_year"])
# Out:
#      start_year  end_year            region            mean_wind_speed
# 0       1956       1963          AUVERGNE RHONE ALPES     11.338715
# 13      1963       1970          AUVERGNE RHONE ALPES     11.442988
# 26      1971       1978          AUVERGNE RHONE ALPES     11.309456
# 39      1979       1985          AUVERGNE RHONE ALPES     10.752927
# 52      1986       1992          AUVERGNE RHONE ALPES      9.638900
# 65      1993       2000          AUVERGNE RHONE ALPES      8.802930
# 78      2001       2008          AUVERGNE RHONE ALPES      8.944318
# 91      2009       2015          AUVERGNE RHONE ALPES      9.483798
# 104     2016       2022          AUVERGNE RHONE ALPES      9.682034
# 1       1956       1963       BOURGOGNE FRANCHE COMTE     11.238958
# 14      1963       1970       BOURGOGNE FRANCHE COMTE     11.402320
# 27      1971       1978       BOURGOGNE FRANCHE COMTE     10.893277
# 40      1979       1985       BOURGOGNE FRANCHE COMTE     10.901082
# 53      1986       1992       BOURGOGNE FRANCHE COMTE      9.632057
# 66      1993       2000       BOURGOGNE FRANCHE COMTE      8.882614
# 79      2001       2008       BOURGOGNE FRANCHE COMTE      9.133416
# 92      2009       2015       BOURGOGNE FRANCHE COMTE      9.022990
# 105     2016       2022       BOURGOGNE FRANCHE COMTE      9.708294
# 2       1956       1963                      BRETAGNE     19.635682
# 15      1963       1970                      BRETAGNE     19.894133
# 28      1971       1978                      BRETAGNE     19.673583
# 41      1979       1985                      BRETAGNE     19.956961
# 54      1986       1992                      BRETAGNE     16.595460
# 67      1993       2000                      BRETAGNE     15.452233
# 80      2001       2008                      BRETAGNE     15.332418
# 93      2009       2015                      BRETAGNE     15.527002
# 106     2016       2022                      BRETAGNE     15.798083
# 3       1956       1963           CENTRE VAL DE LOIRE     13.154594
# 16      1963       1970           CENTRE VAL DE LOIRE     13.136347
# 29      1971       1978           CENTRE VAL DE LOIRE     13.011396
# 42      1979       1985           CENTRE VAL DE LOIRE     14.051956
# 55      1986       1992           CENTRE VAL DE LOIRE     13.459415
# 68      1993       2000           CENTRE VAL DE LOIRE     12.279956
# 81      2001       2008           CENTRE VAL DE LOIRE     11.646751
# 94      2009       2015           CENTRE VAL DE LOIRE     10.634705
# 107     2016       2022           CENTRE VAL DE LOIRE     10.907910
# 4       1956       1963                         CORSE     16.418537
# 17      1963       1970                         CORSE     18.815445
# 30      1971       1978                         CORSE     16.956424
# 43      1979       1985                         CORSE     17.153042
# 56      1986       1992                         CORSE     15.243625
# 69      1993       2000                         CORSE     13.414708
# 82      2001       2008                         CORSE     12.649612
# 95      2009       2015                         CORSE     12.198762
# 108     2016       2022                         CORSE     12.919172
# 5       1956       1963                     GRAND EST     11.112465
# 18      1963       1970                     GRAND EST     11.456989
# 31      1971       1978                     GRAND EST     11.636271
# 44      1979       1985                     GRAND EST     12.471291
# 57      1986       1992                     GRAND EST     10.844972
# 70      1993       2000                     GRAND EST     10.090077
# 83      2001       2008                     GRAND EST     10.786554
# 96      2009       2015                     GRAND EST     10.656154
# 109     2016       2022                     GRAND EST     11.290179
# 6       1956       1963               HAUTS DE FRANCE     16.783530
# 19      1963       1970               HAUTS DE FRANCE     16.704063
# 32      1971       1978               HAUTS DE FRANCE     16.976181
# 45      1979       1985               HAUTS DE FRANCE     17.068436
# 58      1986       1992               HAUTS DE FRANCE     15.432665
# 71      1993       2000               HAUTS DE FRANCE     14.143047
# 84      2001       2008               HAUTS DE FRANCE     14.494514
# 97      2009       2015               HAUTS DE FRANCE     14.520005
# 110     2016       2022               HAUTS DE FRANCE     14.409244
# 7       1956       1963                 ILE DE FRANCE     14.320517
# 20      1963       1970                 ILE DE FRANCE     14.111049
# 33      1971       1978                 ILE DE FRANCE     13.746433
# 46      1979       1985                 ILE DE FRANCE     13.891561
# 59      1986       1992                 ILE DE FRANCE     13.486013
# 72      1993       2000                 ILE DE FRANCE     12.723988
# 85      2001       2008                 ILE DE FRANCE     12.196367
# 98      2009       2015                 ILE DE FRANCE     11.354912
# 111     2016       2022                 ILE DE FRANCE     11.661722
# 8       1956       1963                     NORMANDIE     17.661198
# 21      1963       1970                     NORMANDIE     17.397737
# 34      1971       1978                     NORMANDIE     17.526505
# 47      1979       1985                     NORMANDIE     18.017268
# 60      1986       1992                     NORMANDIE     19.347652
# 73      1993       2000                     NORMANDIE     16.078189
# 86      2001       2008                     NORMANDIE     15.006773
# 99      2009       2015                     NORMANDIE     14.835382
# 112     2016       2022                     NORMANDIE     15.507500
# 9       1956       1963            NOUVELLE AQUITAINE     12.367332
# 22      1963       1970            NOUVELLE AQUITAINE     12.322679
# 35      1971       1978            NOUVELLE AQUITAINE     11.823082
# 48      1979       1985            NOUVELLE AQUITAINE     12.099741
# 61      1986       1992            NOUVELLE AQUITAINE     10.355396
# 74      1993       2000            NOUVELLE AQUITAINE     10.634012
# 87      2001       2008            NOUVELLE AQUITAINE     10.799622
# 100     2009       2015            NOUVELLE AQUITAINE     10.401706
# 113     2016       2022            NOUVELLE AQUITAINE     10.418767
# 10      1956       1963                     OCCITANIE     15.637129
# 23      1963       1970                     OCCITANIE     17.266532
# 36      1971       1978                     OCCITANIE     17.586310
# 49      1979       1985                     OCCITANIE     17.149728
# 62      1986       1992                     OCCITANIE     12.521486
# 75      1993       2000                     OCCITANIE     12.194565
# 88      2001       2008                     OCCITANIE     12.189520
# 101     2009       2015                     OCCITANIE     12.472360
# 114     2016       2022                     OCCITANIE     12.110637
# 11      1956       1963              PAYS DE LA LOIRE     15.401042
# 24      1963       1970              PAYS DE LA LOIRE     14.704340
# 37      1971       1978              PAYS DE LA LOIRE     14.444722
# 50      1979       1985              PAYS DE LA LOIRE     14.225057
# 63      1986       1992              PAYS DE LA LOIRE     14.276284
# 76      1993       2000              PAYS DE LA LOIRE     13.705246
# 89      2001       2008              PAYS DE LA LOIRE     13.463805
# 102     2009       2015              PAYS DE LA LOIRE     12.882450
# 115     2016       2022              PAYS DE LA LOIRE     12.700975
# 12      1956       1963    PROVENCE ALPES COTE D'AZUR     16.806800
# 25      1963       1970    PROVENCE ALPES COTE D'AZUR     16.827580
# 38      1971       1978    PROVENCE ALPES COTE D'AZUR     15.346513
# 51      1979       1985    PROVENCE ALPES COTE D'AZUR     16.108099
# 64      1986       1992    PROVENCE ALPES COTE D'AZUR     12.712274
# 77      1993       2000    PROVENCE ALPES COTE D'AZUR     10.663762
# 90      2001       2008    PROVENCE ALPES COTE D'AZUR     10.342947
# 103     2009       2015    PROVENCE ALPES COTE D'AZUR     10.867709
# 116     2016       2022    PROVENCE ALPES COTE D'AZUR     10.695835

# %%
# periodes
periods = [
    (1956, 1963),
    (1963, 1970),
    (1971, 1978),
    (1979, 1985),
    (1986, 1992),
    (1993, 2000),
    (2001, 2008),
    (2009, 2015),
    (2016, 2022)
]

# Calculer moyenne vent par péridoe et région
mean_wind_speeds = []
for start, end in periods:
    period_df = df_date_region[(df_date_region["AAAAMM"].dt.year >= start) & 
                               (df_date_region["AAAAMM"].dt.year <= end)]
    period_df_grouped = period_df.groupby("region")["vent_speed_inst_moy_mensu"].mean().reset_index()
    period_df_grouped["period"] = f"{start}-{end}"
    mean_wind_speeds.append(period_df_grouped)

# Concatenate
df_mean_wind_speeds = pd.concat(mean_wind_speeds)

# Graphique
fig = px.bar(df_mean_wind_speeds, x="region", y="vent_speed_inst_moy_mensu", color="period",
             title="Vitesse moyenne du vent par région par période de 7 ans",
             labels={"vent_speed_inst_moy_mensu": "Vitesse moyenne du vent (km/h)", "region": "Région", "period": "Période"},
             barmode="group")

fig.show()

# %% [markdown]
# Globalement le vent remonte bien depuis la période "2009". Même depuis la période "1993" sur certaines régions

# %%
# Periods
periods = [
    (2001, 2008),
    (2009, 2015),
    (2016, 2022)
]

counts = []

# Loop
for start, end in periods:
    for region in df_date_region['region'].unique():
        period_df = df_date_region[(df_date_region["AAAAMM"].dt.year >= start) & 
                                   (df_date_region["AAAAMM"].dt.year <= end) & 
                                   (df_date_region["region"] == region)]
        count = period_df[period_df["vent_speed_inst_moy_mensu"] > 14].shape[0]
        counts.append({"region": region, "period": f"{start}-{end}", "count": count})

# Convert to DataFrame
df_counts = pd.DataFrame(counts)

# Graphique
fig = px.bar(df_counts, x="region", y="count", color="period",
             title="Nombre de mois où la vitesse moyenne du vent est supérieure à 14 km/h par région",
             labels={"count": "Nombre de mois", "region": "Région", "period": "Période"},
             barmode="group")

fig.show()

# %% [markdown]
# Même si la force du vent augmente en moyenne, il peut y avoir moins de mois venteux sur certaines zones, et plus sur d'autres

# %% [markdown]
# - intéressons nous aux stations météos :

# %%
# calculer le nombre de station différentes
df['NUM_POSTE'].nunique()
print(f"Nombre de stations différentes: {df['NUM_POSTE'].nunique()}")
# Out:
# Nombre de stations différentes: 1129

# %% [markdown]
# Est ce que notre dataset est représentatif, et est ce que nos stations météos sont bien réparties sur le territoire ?

# %%
# Supprimer les doublons basés sur la colonne 'NUM_POSTE'
df_unique = df.drop_duplicates(subset=['NUM_POSTE'])

# Créer une carte centrée sur la moyenne des coordonnées
carte = folium.Map(location=[df_unique['LAT'].mean(), df_unique['LON'].mean()], zoom_start=6)

# Ajouter un marqueur pour chaque station unique
for idx, row in df_unique.iterrows():
    popup_content = f"Station: {row['NUM_POSTE']}<br>Nom Usuel: {row['NOM_USUEL']}"
    folium.Marker(
        location=[row['LAT'], row['LON']],
        popup=folium.Popup(popup_content, max_width=300),
        tooltip=f"Station: {row['NUM_POSTE']}",
        icon=folium.Icon(icon='wind', prefix='fa', icon_size=(28, 28))
    ).add_to(carte)

# Sauvegarder la carte
carte.save("carte_stations_meteo.html")

# %%
# Supprimer les lignes avec la station outlier
df= df[df["NUM_POSTE"] != 17300848]

# %% [markdown]
# Définir la station avec le moins de valeurs manquantes. Elle servira également à la baseline de notre premier modèle

# %%
# Filtrer les données pour la période de 1950 à 2022
df_filtered = df[(df['AAAAMM'] >= '1950-01-01') & (df['AAAAMM'] <= '2022-12-31')]

# Compter le nombre de données pour chaque station
station_counts = df_filtered['NUM_POSTE'].value_counts()

# Trouver la station avec le plus de données
most_data_station = station_counts.idxmax()
most_data_count = station_counts.max()

print(f"La station avec le plus de données est {most_data_station} avec {most_data_count} enregistrements.")
# Out:
# La station avec le plus de données est 28070001 avec 876 enregistrements.

# %%
# Filtrer les données pour la station 28070001
df_station = df[df["NUM_POSTE"] == 28070001]

# Créer un graphique interactif
fig = px.line(df_station, x="AAAAMM", y="vent_speed_inst_moy_mensu", title="Vitesse moyenne du vent pour la station 28070001")
fig.show()

# %% [markdown]
# Sur cette station particulière (Pays-de-la-Loire) nous sommes cohérents avec les stats régionales..visualisons des stations plus exposés aux vents dans le Nord-pas de Calais (62), la Somme(80), le finistère (29)

# %%
# choisir une station ayant au moins 300 enregistrements dans le département 29
stations_29 = df[df["departement_num"] == 29]
stations_29_counts = stations_29["NUM_POSTE"].value_counts()
stations_29_filtered = stations_29_counts[stations_29_counts >= 300]
chosen_station = stations_29_filtered.idxmax()

# Filtrer les données
df_chosen_station = df[df["NUM_POSTE"] == chosen_station]

# Graphique
fig = px.line(df_chosen_station, x="AAAAMM", y="vent_speed_inst_moy_mensu", title=f"Vitesse moyenne du vent pour la station {chosen_station}")
fig.show()

# %%
# choisir une station ayant au moins 300 enregistrements dans le département80
stations80 = df[df["departement_num"] == 80]
stations80_counts = stations80["NUM_POSTE"].value_counts()
stations80_filtered = stations80_counts[stations80_counts >= 300]
chosen_station = stations80_filtered.idxmax()

# Filtrer
df_chosen_station = df[df["NUM_POSTE"] == chosen_station]

# Graphique
fig = px.line(df_chosen_station, x="AAAAMM", y="vent_speed_inst_moy_mensu", title=f"Vitesse moyenne du vent pour la station {chosen_station}")
fig.show()

# %%
# choisir une station ayant au moins 300 enregistrements dans le département29 = df[df["departement_num"] == 29]
stations_29 = df[df["departement_num"] == 29]
stations29_counts = stations_29["NUM_POSTE"].value_counts()
stations29_filtered = stations29_counts[stations29_counts >= 300]
chosen_station = stations29_filtered.idxmax()

# Filtrer
df_chosen_station = df[df["NUM_POSTE"] == chosen_station]

# Graphique
fig = px.line(df_chosen_station, x="AAAAMM", y="vent_speed_inst_moy_mensu", title=f"Vitesse moyenne du vent pour la station {chosen_station}")
fig.show()

# %%
# choisir une station aléatoire
station = df_unique.sample(22)
station

# Filtrer
df_station = df[df["NUM_POSTE"] == station["NUM_POSTE"].values[0]]

# Graphique
fig = px.line(df_station, x="AAAAMM", y="vent_speed_inst_moy_mensu", title=f"Vitesse moyenne du vent pour la station {station['NUM_POSTE'].values[0]}")
fig.show()

# %% [markdown]
# Examinons les mois les plus venteux et les moins venteux

# %%
# List of month names and their corresponding numbers
months = [
    ("janvier", 1), ("février", 2), ("mars", 3), ("avril", 4),
    ("mai", 5), ("juin", 6), ("juillet", 7), ("août", 8),
    ("septembre", 9), ("octobre", 10), ("novembre", 11), ("décembre", 12)
]

# Loop et Graphique
for month_name, month_num in months:
    df_month = df_monthly[df_monthly["AAAAMM"].dt.month == month_num]
    fig = px.line(df_month, x="AAAAMM", y="vent_speed_inst_moy_mensu", title=f"Vitesse moyenne du vent en France pour le mois de {month_name}")
    fig.show()

# %%
# classer les résultats du mois le plus venteux au moins venteux
df_monthly["month"] = df_monthly["AAAAMM"].dt.month
df_monthly["month_name"] = df_monthly["AAAAMM"].dt.strftime("%B")
df_monthly_grouped = df_monthly.groupby("month_name")["vent_speed_inst_moy_mensu"].mean().reset_index()
df_monthly_grouped = df_monthly_grouped.sort_values(by="vent_speed_inst_moy_mensu", ascending=False)

# Graphique
fig = px.bar(df_monthly_grouped, x="month_name", y="vent_speed_inst_moy_mensu",
             title="Vitesse moyenne du vent en France par mois",
             labels={"vent_speed_inst_moy_mensu": "Vitesse moyenne du vent (km/h)", "month_name": "Mois"},
             color="month_name")

fig.show()

# %%
# Extract
df_date_region["month"] = df_date_region["AAAAMM"].dt.month
df_date_region["month_name"] = df_date_region["AAAAMM"].dt.strftime("%B")

# Group by
df_date_region_grouped = df_date_region.groupby(["region", "month_name"])["vent_speed_inst_moy_mensu"].mean().reset_index()

# Trier
df_date_region_grouped = df_date_region_grouped.sort_values(by=["region", "vent_speed_inst_moy_mensu"], ascending=[True, False])

# Graphique
fig = px.bar(df_date_region_grouped, x="region", y="vent_speed_inst_moy_mensu",
             title="Vitesse moyenne du vent par région et par mois",
             labels={"vent_speed_inst_moy_mensu": "Vitesse moyenne du vent (km/h)", "region": "Région", "month_name": "Mois"},
             color="month_name",
             category_orders={"month_name": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]})

# Update
fig.update_layout(xaxis={'categoryorder':'total descending'},
                  yaxis_title="Vitesse moyenne du vent (km/h)",
                  xaxis_title="Région",
                  legend_title="Mois")

fig.show()

# %% [markdown]
# - nos stations sont bien réparties sur le territoire français et nous permettent une analyse globale assez complète
# - en France le vent augmente globalement depuis 2000/2010.
# - est-ce dû au réchauffement climatique ou à d'autres phénomènes ? la question reste ouverte
# - mais le vent moyen n'est pas forcément très élevé et ne suffirait pas à faire tourner une éolinenne en continu eet/ou sur certaines zones
# - certaines régions sont clairement identifiés comme à fort potentiel avec des vents plus forts que la moyenne nationale
# - même si le vent n'augmente pas dans certaines régions il reste en moyenne suffisament élevé pour faire tourner une éolienne (ex :; Pays-de-la-Loire)
# - certaines régions seraient intéressantes à analyser pour l'implémentation car un vent moyen en augmentation malgrès une moyenne annuelle assez loin des 14km/h
# - il reste des zones peu propices à l'implémentation d'éolienne en France même si le vent augmentait
# - les mois les plus venteux en France sont janvier, février et mars
# - les mois le moins venteux en France sont juillet, août et septembre
#
# - les fortes variations locales de la vitesse du vent peuvent être un frein c'est pourquoi :
#     - 1°  afin de créer un modèle assez précis pour tenter determiner la force du vent à 7 an
#     - 2°  nous allons travailler sur la station de Chartres (complète et moins d'aléas) pour ensuite travailler une région et ensuite au niveau "France"
#     - 3° puis nous supperposerons ensuite les données prédites sur une carte comportant les éoliennes déjà existantes, et un calque des zones "autorisés" à l'implémentation
