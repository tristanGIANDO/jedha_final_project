# %%
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from calendar import monthrange
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

# %%
# Masquer les SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv("https://jedha-final-project-jrat.s3.amazonaws.com/datameteo_france_1950-2022_clean_04.csv")

# %%
df_stations_authorized = df[df["is_authorized"] == True]

# %%
df_stations_old = df_stations_authorized.groupby(["NUM_POSTE"]).max()
print(len(df_stations_old))
# Out:
# 412

# %%
# filter out station qui n'ont pas de données récentes (2022)
last_year = df["Year"].max()
mask = df_stations_old["Year"]!=last_year
df_stations_old = df_stations_old[mask]
stations_old = df_stations_old.index.to_list()
df_recent = df_stations_authorized[~df_stations_authorized["NUM_POSTE"].isin(stations_old)]

# %%
print(len(df_recent.groupby(["NUM_POSTE"]).max()))
# Out:
# 274

# %%
# la précédente exploration nous a permis de conclure que pour prédire à horizon 7 ans
# le modèle ne performait (MAPE moyenne de 13%) qu'à partir de 168 mois (14 ans) de continuité des données
# on filtre donc sur les stations qui ont 12 mois sur chaque année entre 2022 et 2009 inclus au minimum

stations = df_recent["NUM_POSTE"].unique()
to_drop = []

for num_station in stations:
    df_station = df_recent[df_recent["NUM_POSTE"]==num_station]

    for year in range(last_year,last_year-14,-1):
        nb_missing_month = 0
        try:
            df_station_year = df_station[df_station["Year"]==year]
            nb_missing_month = 12 - len(df_station_year["Month"].unique().tolist())
            if nb_missing_month > 0:
                to_drop.append(num_station)
                print(f"Drop station N°{num_station}")
                print(f"{nb_missing_month} manquants en {year}\n\n")
            else:
                print(f"Station N°{num_station} has {df_station_year["Month"].count()} months in {year}")

        except Exception as e:
            to_drop.append(num_station)
            print(e)
            print()
            print(f"Drop station N°{num_station}")
            print(f"{year} est manquante\n\n")

    print()
# Out:
# Station N°1014002 has 12 months in 2022
# Station N°1014002 has 12 months in 2021
# Station N°1014002 has 12 months in 2020
# Station N°1014002 has 12 months in 2019
# Station N°1014002 has 12 months in 2018
# Station N°1014002 has 12 months in 2017
# Station N°1014002 has 12 months in 2016
# Station N°1014002 has 12 months in 2015
# Station N°1014002 has 12 months in 2014
# Station N°1014002 has 12 months in 2013
# Station N°1014002 has 12 months in 2012
# Station N°1014002 has 12 months in 2011
# Station N°1014002 has 12 months in 2010
# Station N°1014002 has 12 months in 2009
#
# Station N°1071001 has 12 months in 2022
# Station N°1071001 has 12 months in 2021
# Station N°1071001 has 12 months in 2020
# Station N°1071001 has 12 months in 2019
# Station N°1071001 has 12 months in 2018
# Station N°1071001 has 12 months in 2017
# Station N°1071001 has 12 months in 2016
# Station N°1071001 has 12 months in 2015
# Station N°1071001 has 12 months in 2014
# Station N°1071001 has 12 months in 2013
# Station N°1071001 has 12 months in 2012
# Station N°1071001 has 12 months in 2011
# Station N°1071001 has 12 months in 2010
# Station N°1071001 has 12 months in 2009
#
# Station N°1414001 has 12 months in 2022
# Station N°1414001 has 12 months in 2021
# Station N°1414001 has 12 months in 2020
# Station N°1414001 has 12 months in 2019
# Station N°1414001 has 12 months in 2018
# Station N°1414001 has 12 months in 2017
# Station N°1414001 has 12 months in 2016
# Station N°1414001 has 12 months in 2015
# Station N°1414001 has 12 months in 2014
# Station N°1414001 has 12 months in 2013
# Station N°1414001 has 12 months in 2012
# Station N°1414001 has 12 months in 2011
# Station N°1414001 has 12 months in 2010
# Station N°1414001 has 12 months in 2009
#
# Station N°2037002 has 12 months in 2022
# Station N°2037002 has 12 months in 2021
# Station N°2037002 has 12 months in 2020
# Station N°2037002 has 12 months in 2019
# Station N°2037002 has 12 months in 2018
# Station N°2037002 has 12 months in 2017
# Station N°2037002 has 12 months in 2016
# Station N°2037002 has 12 months in 2015
# Station N°2037002 has 12 months in 2014
# Station N°2037002 has 12 months in 2013
# Station N°2037002 has 12 months in 2012
# Station N°2037002 has 12 months in 2011
# Station N°2037002 has 12 months in 2010
# Station N°2037002 has 12 months in 2009
#
# Station N°2173002 has 12 months in 2022
# Station N°2173002 has 12 months in 2021
# Station N°2173002 has 12 months in 2020
# Station N°2173002 has 12 months in 2019
# Station N°2173002 has 12 months in 2018
# Station N°2173002 has 12 months in 2017
# Station N°2173002 has 12 months in 2016
# Station N°2173002 has 12 months in 2015
# Station N°2173002 has 12 months in 2014
# Station N°2173002 has 12 months in 2013
# Station N°2173002 has 12 months in 2012
# Station N°2173002 has 12 months in 2011
# Station N°2173002 has 12 months in 2010
# Station N°2173002 has 12 months in 2009
#
# Station N°2320001 has 12 months in 2022
# Station N°2320001 has 12 months in 2021
# Station N°2320001 has 12 months in 2020
# Station N°2320001 has 12 months in 2019
# Station N°2320001 has 12 months in 2018
# Station N°2320001 has 12 months in 2017
# Station N°2320001 has 12 months in 2016
# Station N°2320001 has 12 months in 2015
# Station N°2320001 has 12 months in 2014
# Station N°2320001 has 12 months in 2013
# Station N°2320001 has 12 months in 2012
# Station N°2320001 has 12 months in 2011
# Station N°2320001 has 12 months in 2010
# Station N°2320001 has 12 months in 2009
#
# Station N°2321002 has 12 months in 2022
# Station N°2321002 has 12 months in 2021
# Station N°2321002 has 12 months in 2020
# Station N°2321002 has 12 months in 2019
# Station N°2321002 has 12 months in 2018
# Station N°2321002 has 12 months in 2017
# Station N°2321002 has 12 months in 2016
# Station N°2321002 has 12 months in 2015
# Station N°2321002 has 12 months in 2014
# Station N°2321002 has 12 months in 2013
# Station N°2321002 has 12 months in 2012
# Station N°2321002 has 12 months in 2011
# Station N°2321002 has 12 months in 2010
# Station N°2321002 has 12 months in 2009
#
# Station N°2705001 has 12 months in 2022
# Station N°2705001 has 12 months in 2021
# Station N°2705001 has 12 months in 2020
# Station N°2705001 has 12 months in 2019
# Station N°2705001 has 12 months in 2018
# Station N°2705001 has 12 months in 2017
# Station N°2705001 has 12 months in 2016
# Drop station N°2705001
# 8 manquants en 2015
#
#
# Drop station N°2705001
# 12 manquants en 2014
#
#
# Drop station N°2705001
# 7 manquants en 2013
#
#
# Station N°2705001 has 12 months in 2012
# Station N°2705001 has 12 months in 2011
# Drop station N°2705001
# 2 manquants en 2010
#
#
# Station N°2705001 has 12 months in 2009
#
# Station N°3155003 has 12 months in 2022
# Station N°3155003 has 12 months in 2021
# Station N°3155003 has 12 months in 2020
# Station N°3155003 has 12 months in 2019
# Station N°3155003 has 12 months in 2018
# Station N°3155003 has 12 months in 2017
# Station N°3155003 has 12 months in 2016
# Station N°3155003 has 12 months in 2015
# Station N°3155003 has 12 months in 2014
# Station N°3155003 has 12 months in 2013
# Station N°3155003 has 12 months in 2012
# Station N°3155003 has 12 months in 2011
# Station N°3155003 has 12 months in 2010
# Station N°3155003 has 12 months in 2009
#
# Station N°3180001 has 12 months in 2022
# Station N°3180001 has 12 months in 2021
# Station N°3180001 has 12 months in 2020
# Station N°3180001 has 12 months in 2019
# Station N°3180001 has 12 months in 2018
# Station N°3180001 has 12 months in 2017
# Station N°3180001 has 12 months in 2016
# Station N°3180001 has 12 months in 2015
# Station N°3180001 has 12 months in 2014
# Station N°3180001 has 12 months in 2013
# Station N°3180001 has 12 months in 2012
# Station N°3180001 has 12 months in 2011
# Station N°3180001 has 12 months in 2010
# Station N°3180001 has 12 months in 2009
#
# Station N°3185007 has 12 months in 2022
# Station N°3185007 has 12 months in 2021
# Station N°3185007 has 12 months in 2020
# Station N°3185007 has 12 months in 2019
# Station N°3185007 has 12 months in 2018
# Station N°3185007 has 12 months in 2017
# Station N°3185007 has 12 months in 2016
# Station N°3185007 has 12 months in 2015
# Station N°3185007 has 12 months in 2014
# Station N°3185007 has 12 months in 2013
# Station N°3185007 has 12 months in 2012
# Station N°3185007 has 12 months in 2011
# Station N°3185007 has 12 months in 2010
# Station N°3185007 has 12 months in 2009
#
# Station N°4019001 has 12 months in 2022
# Station N°4019001 has 12 months in 2021
# Station N°4019001 has 12 months in 2020
# Station N°4019001 has 12 months in 2019
# Station N°4019001 has 12 months in 2018
# Station N°4019001 has 12 months in 2017
# Station N°4019001 has 12 months in 2016
# Station N°4019001 has 12 months in 2015
# Station N°4019001 has 12 months in 2014
# Station N°4019001 has 12 months in 2013
# Station N°4019001 has 12 months in 2012
# Station N°4019001 has 12 months in 2011
# Station N°4019001 has 12 months in 2010
# Station N°4019001 has 12 months in 2009
#
# Station N°4096401 has 12 months in 2022
# Station N°4096401 has 12 months in 2021
# Station N°4096401 has 12 months in 2020
# Station N°4096401 has 12 months in 2019
# Station N°4096401 has 12 months in 2018
# Station N°4096401 has 12 months in 2017
# Station N°4096401 has 12 months in 2016
# Station N°4096401 has 12 months in 2015
# Station N°4096401 has 12 months in 2014
# Station N°4096401 has 12 months in 2013
# Station N°4096401 has 12 months in 2012
# Station N°4096401 has 12 months in 2011
# Station N°4096401 has 12 months in 2010
# Station N°4096401 has 12 months in 2009
#
# Station N°4134002 has 12 months in 2022
# Station N°4134002 has 12 months in 2021
# Station N°4134002 has 12 months in 2020
# Station N°4134002 has 12 months in 2019
# Station N°4134002 has 12 months in 2018
# Station N°4134002 has 12 months in 2017
# Station N°4134002 has 12 months in 2016
# Station N°4134002 has 12 months in 2015
# Station N°4134002 has 12 months in 2014
# Station N°4134002 has 12 months in 2013
# Station N°4134002 has 12 months in 2012
# Station N°4134002 has 12 months in 2011
# Station N°4134002 has 12 months in 2010
# Station N°4134002 has 12 months in 2009
#
# Station N°4136001 has 12 months in 2022
# Station N°4136001 has 12 months in 2021
# Station N°4136001 has 12 months in 2020
# Station N°4136001 has 12 months in 2019
# Station N°4136001 has 12 months in 2018
# Station N°4136001 has 12 months in 2017
# Station N°4136001 has 12 months in 2016
# Station N°4136001 has 12 months in 2015
# Station N°4136001 has 12 months in 2014
# Station N°4136001 has 12 months in 2013
# Station N°4136001 has 12 months in 2012
# Station N°4136001 has 12 months in 2011
# Station N°4136001 has 12 months in 2010
# Drop station N°4136001
# 11 manquants en 2009
#
#
#
# Station N°4209005 has 12 months in 2022
# Station N°4209005 has 12 months in 2021
# Station N°4209005 has 12 months in 2020
# Station N°4209005 has 12 months in 2019
# Station N°4209005 has 12 months in 2018
# Station N°4209005 has 12 months in 2017
# Station N°4209005 has 12 months in 2016
# Station N°4209005 has 12 months in 2015
# Station N°4209005 has 12 months in 2014
# Station N°4209005 has 12 months in 2013
# Station N°4209005 has 12 months in 2012
# Station N°4209005 has 12 months in 2011
# Station N°4209005 has 12 months in 2010
# Station N°4209005 has 12 months in 2009
#
# Station N°5044400 has 12 months in 2022
# Station N°5044400 has 12 months in 2021
# Station N°5044400 has 12 months in 2020
# Station N°5044400 has 12 months in 2019
# Station N°5044400 has 12 months in 2018
# Station N°5044400 has 12 months in 2017
# Station N°5044400 has 12 months in 2016
# Station N°5044400 has 12 months in 2015
# Station N°5044400 has 12 months in 2014
# Station N°5044400 has 12 months in 2013
# Station N°5044400 has 12 months in 2012
# Station N°5044400 has 12 months in 2011
# Drop station N°5044400
# 7 manquants en 2010
#
#
# Drop station N°5044400
# 12 manquants en 2009
#
#
#
# Station N°5046001 has 12 months in 2022
# Station N°5046001 has 12 months in 2021
# Station N°5046001 has 12 months in 2020
# Station N°5046001 has 12 months in 2019
# Station N°5046001 has 12 months in 2018
# Station N°5046001 has 12 months in 2017
# Station N°5046001 has 12 months in 2016
# Station N°5046001 has 12 months in 2015
# Station N°5046001 has 12 months in 2014
# Station N°5046001 has 12 months in 2013
# Station N°5046001 has 12 months in 2012
# Station N°5046001 has 12 months in 2011
# Station N°5046001 has 12 months in 2010
# Station N°5046001 has 12 months in 2009
#
# Station N°5055001 has 12 months in 2022
# Station N°5055001 has 12 months in 2021
# Station N°5055001 has 12 months in 2020
# Station N°5055001 has 12 months in 2019
# Station N°5055001 has 12 months in 2018
# Station N°5055001 has 12 months in 2017
# Station N°5055001 has 12 months in 2016
# Station N°5055001 has 12 months in 2015
# Station N°5055001 has 12 months in 2014
# Station N°5055001 has 12 months in 2013
# Station N°5055001 has 12 months in 2012
# Station N°5055001 has 12 months in 2011
# Station N°5055001 has 12 months in 2010
# Station N°5055001 has 12 months in 2009
#
# Station N°5061009 has 12 months in 2022
# Station N°5061009 has 12 months in 2021
# Station N°5061009 has 12 months in 2020
# Station N°5061009 has 12 months in 2019
# Station N°5061009 has 12 months in 2018
# Station N°5061009 has 12 months in 2017
# Station N°5061009 has 12 months in 2016
# Station N°5061009 has 12 months in 2015
# Station N°5061009 has 12 months in 2014
# Station N°5061009 has 12 months in 2013
# Station N°5061009 has 12 months in 2012
# Station N°5061009 has 12 months in 2011
# Station N°5061009 has 12 months in 2010
# Station N°5061009 has 12 months in 2009
#
# Station N°5070003 has 12 months in 2022
# Station N°5070003 has 12 months in 2021
# Station N°5070003 has 12 months in 2020
# Station N°5070003 has 12 months in 2019
# Station N°5070003 has 12 months in 2018
# Station N°5070003 has 12 months in 2017
# Station N°5070003 has 12 months in 2016
# Station N°5070003 has 12 months in 2015
# Station N°5070003 has 12 months in 2014
# Station N°5070003 has 12 months in 2013
# Station N°5070003 has 12 months in 2012
# Station N°5070003 has 12 months in 2011
# Station N°5070003 has 12 months in 2010
# Station N°5070003 has 12 months in 2009
#
# Station N°5077402 has 12 months in 2022
# Station N°5077402 has 12 months in 2021
# Station N°5077402 has 12 months in 2020
# Station N°5077402 has 12 months in 2019
# Station N°5077402 has 12 months in 2018
# Station N°5077402 has 12 months in 2017
# Station N°5077402 has 12 months in 2016
# Station N°5077402 has 12 months in 2015
# Station N°5077402 has 12 months in 2014
# Station N°5077402 has 12 months in 2013
# Station N°5077402 has 12 months in 2012
# Station N°5077402 has 12 months in 2011
# Station N°5077402 has 12 months in 2010
# Station N°5077402 has 12 months in 2009
#
# Station N°5136002 has 12 months in 2022
# Station N°5136002 has 12 months in 2021
# Station N°5136002 has 12 months in 2020
# Station N°5136002 has 12 months in 2019
# Station N°5136002 has 12 months in 2018
# Station N°5136002 has 12 months in 2017
# Station N°5136002 has 12 months in 2016
# Station N°5136002 has 12 months in 2015
# Station N°5136002 has 12 months in 2014
# Station N°5136002 has 12 months in 2013
# Station N°5136002 has 12 months in 2012
# Station N°5136002 has 12 months in 2011
# Drop station N°5136002
# 7 manquants en 2010
#
#
# Drop station N°5136002
# 4 manquants en 2009
#
#
#
# Station N°5145002 has 12 months in 2022
# Station N°5145002 has 12 months in 2021
# Station N°5145002 has 12 months in 2020
# Station N°5145002 has 12 months in 2019
# Station N°5145002 has 12 months in 2018
# Station N°5145002 has 12 months in 2017
# Station N°5145002 has 12 months in 2016
# Station N°5145002 has 12 months in 2015
# Station N°5145002 has 12 months in 2014
# Station N°5145002 has 12 months in 2013
# Station N°5145002 has 12 months in 2012
# Station N°5145002 has 12 months in 2011
# Station N°5145002 has 12 months in 2010
# Station N°5145002 has 12 months in 2009
#
# Station N°5170001 has 12 months in 2022
# Station N°5170001 has 12 months in 2021
# Station N°5170001 has 12 months in 2020
# Station N°5170001 has 12 months in 2019
# Station N°5170001 has 12 months in 2018
# Station N°5170001 has 12 months in 2017
# Station N°5170001 has 12 months in 2016
# Station N°5170001 has 12 months in 2015
# Station N°5170001 has 12 months in 2014
# Station N°5170001 has 12 months in 2013
# Station N°5170001 has 12 months in 2012
# Station N°5170001 has 12 months in 2011
# Station N°5170001 has 12 months in 2010
# Station N°5170001 has 12 months in 2009
#
# Station N°6005001 has 12 months in 2022
# Station N°6005001 has 12 months in 2021
# Station N°6005001 has 12 months in 2020
# Station N°6005001 has 12 months in 2019
# Station N°6005001 has 12 months in 2018
# Station N°6005001 has 12 months in 2017
# Station N°6005001 has 12 months in 2016
# Station N°6005001 has 12 months in 2015
# Station N°6005001 has 12 months in 2014
# Station N°6005001 has 12 months in 2013
# Station N°6005001 has 12 months in 2012
# Station N°6005001 has 12 months in 2011
# Station N°6005001 has 12 months in 2010
# Station N°6005001 has 12 months in 2009
#
# Station N°6081001 has 12 months in 2022
# Station N°6081001 has 12 months in 2021
# Station N°6081001 has 12 months in 2020
# Station N°6081001 has 12 months in 2019
# Station N°6081001 has 12 months in 2018
# Station N°6081001 has 12 months in 2017
# Station N°6081001 has 12 months in 2016
# Station N°6081001 has 12 months in 2015
# Station N°6081001 has 12 months in 2014
# Station N°6081001 has 12 months in 2013
# Station N°6081001 has 12 months in 2012
# Station N°6081001 has 12 months in 2011
# Station N°6081001 has 12 months in 2010
# Station N°6081001 has 12 months in 2009
#
# Station N°6094002 has 12 months in 2022
# Station N°6094002 has 12 months in 2021
# Station N°6094002 has 12 months in 2020
# Station N°6094002 has 12 months in 2019
# Station N°6094002 has 12 months in 2018
# Station N°6094002 has 12 months in 2017
# Station N°6094002 has 12 months in 2016
# Station N°6094002 has 12 months in 2015
# Station N°6094002 has 12 months in 2014
# Station N°6094002 has 12 months in 2013
# Station N°6094002 has 12 months in 2012
# Station N°6094002 has 12 months in 2011
# Station N°6094002 has 12 months in 2010
# Station N°6094002 has 12 months in 2009
#
# Station N°7131001 has 12 months in 2022
# Station N°7131001 has 12 months in 2021
# Station N°7131001 has 12 months in 2020
# Station N°7131001 has 12 months in 2019
# Station N°7131001 has 12 months in 2018
# Station N°7131001 has 12 months in 2017
# Station N°7131001 has 12 months in 2016
# Station N°7131001 has 12 months in 2015
# Station N°7131001 has 12 months in 2014
# Station N°7131001 has 12 months in 2013
# Station N°7131001 has 12 months in 2012
# Station N°7131001 has 12 months in 2011
# Drop station N°7131001
# 6 manquants en 2010
#
#
# Drop station N°7131001
# 3 manquants en 2009
#
#
#
# Station N°7202002 has 12 months in 2022
# Drop station N°7202002
# 2 manquants en 2021
#
#
# Station N°7202002 has 12 months in 2020
# Station N°7202002 has 12 months in 2019
# Station N°7202002 has 12 months in 2018
# Station N°7202002 has 12 months in 2017
# Station N°7202002 has 12 months in 2016
# Station N°7202002 has 12 months in 2015
# Station N°7202002 has 12 months in 2014
# Station N°7202002 has 12 months in 2013
# Station N°7202002 has 12 months in 2012
# Station N°7202002 has 12 months in 2011
# Station N°7202002 has 12 months in 2010
# Station N°7202002 has 12 months in 2009
#
# Station N°8145001 has 12 months in 2022
# Station N°8145001 has 12 months in 2021
# Station N°8145001 has 12 months in 2020
# Station N°8145001 has 12 months in 2019
# Station N°8145001 has 12 months in 2018
# Station N°8145001 has 12 months in 2017
# Station N°8145001 has 12 months in 2016
# Station N°8145001 has 12 months in 2015
# Station N°8145001 has 12 months in 2014
# Station N°8145001 has 12 months in 2013
# Station N°8145001 has 12 months in 2012
# Station N°8145001 has 12 months in 2011
# Station N°8145001 has 12 months in 2010
# Station N°8145001 has 12 months in 2009
#
# Station N°8401001 has 12 months in 2022
# Station N°8401001 has 12 months in 2021
# Station N°8401001 has 12 months in 2020
# Station N°8401001 has 12 months in 2019
# Station N°8401001 has 12 months in 2018
# Station N°8401001 has 12 months in 2017
# Station N°8401001 has 12 months in 2016
# Station N°8401001 has 12 months in 2015
# Station N°8401001 has 12 months in 2014
# Station N°8401001 has 12 months in 2013
# Station N°8401001 has 12 months in 2012
# Station N°8401001 has 12 months in 2011
# Station N°8401001 has 12 months in 2010
# Station N°8401001 has 12 months in 2009
#
# Station N°9161003 has 12 months in 2022
# Station N°9161003 has 12 months in 2021
# Station N°9161003 has 12 months in 2020
# Station N°9161003 has 12 months in 2019
# Station N°9161003 has 12 months in 2018
# Station N°9161003 has 12 months in 2017
# Station N°9161003 has 12 months in 2016
# Station N°9161003 has 12 months in 2015
# Station N°9161003 has 12 months in 2014
# Station N°9161003 has 12 months in 2013
# Station N°9161003 has 12 months in 2012
# Station N°9161003 has 12 months in 2011
# Station N°9161003 has 12 months in 2010
# Station N°9161003 has 12 months in 2009
#
# Station N°10057001 has 12 months in 2022
# Station N°10057001 has 12 months in 2021
# Station N°10057001 has 12 months in 2020
# Station N°10057001 has 12 months in 2019
# Station N°10057001 has 12 months in 2018
# Station N°10057001 has 12 months in 2017
# Station N°10057001 has 12 months in 2016
# Station N°10057001 has 12 months in 2015
# Station N°10057001 has 12 months in 2014
# Station N°10057001 has 12 months in 2013
# Station N°10057001 has 12 months in 2012
# Station N°10057001 has 12 months in 2011
# Station N°10057001 has 12 months in 2010
# Station N°10057001 has 12 months in 2009
#
# Station N°10228002 has 12 months in 2022
# Station N°10228002 has 12 months in 2021
# Station N°10228002 has 12 months in 2020
# Station N°10228002 has 12 months in 2019
# Station N°10228002 has 12 months in 2018
# Station N°10228002 has 12 months in 2017
# Station N°10228002 has 12 months in 2016
# Station N°10228002 has 12 months in 2015
# Station N°10228002 has 12 months in 2014
# Station N°10228002 has 12 months in 2013
# Station N°10228002 has 12 months in 2012
# Station N°10228002 has 12 months in 2011
# Station N°10228002 has 12 months in 2010
# Station N°10228002 has 12 months in 2009
#
# Station N°11004001 has 12 months in 2022
# Station N°11004001 has 12 months in 2021
# Station N°11004001 has 12 months in 2020
# Drop station N°11004001
# 1 manquants en 2019
#
#
# Station N°11004001 has 12 months in 2018
# Station N°11004001 has 12 months in 2017
# Station N°11004001 has 12 months in 2016
# Station N°11004001 has 12 months in 2015
# Station N°11004001 has 12 months in 2014
# Station N°11004001 has 12 months in 2013
# Station N°11004001 has 12 months in 2012
# Station N°11004001 has 12 months in 2011
# Station N°11004001 has 12 months in 2010
# Station N°11004001 has 12 months in 2009
#
# Station N°11069001 has 12 months in 2022
# Station N°11069001 has 12 months in 2021
# Station N°11069001 has 12 months in 2020
# Station N°11069001 has 12 months in 2019
# Station N°11069001 has 12 months in 2018
# Station N°11069001 has 12 months in 2017
# Station N°11069001 has 12 months in 2016
# Station N°11069001 has 12 months in 2015
# Station N°11069001 has 12 months in 2014
# Station N°11069001 has 12 months in 2013
# Station N°11069001 has 12 months in 2012
# Station N°11069001 has 12 months in 2011
# Station N°11069001 has 12 months in 2010
# Station N°11069001 has 12 months in 2009
#
# Station N°11076001 has 12 months in 2022
# Station N°11076001 has 12 months in 2021
# Station N°11076001 has 12 months in 2020
# Station N°11076001 has 12 months in 2019
# Station N°11076001 has 12 months in 2018
# Station N°11076001 has 12 months in 2017
# Station N°11076001 has 12 months in 2016
# Station N°11076001 has 12 months in 2015
# Station N°11076001 has 12 months in 2014
# Station N°11076001 has 12 months in 2013
# Station N°11076001 has 12 months in 2012
# Station N°11076001 has 12 months in 2011
# Station N°11076001 has 12 months in 2010
# Station N°11076001 has 12 months in 2009
#
# Station N°11081003 has 12 months in 2022
# Station N°11081003 has 12 months in 2021
# Station N°11081003 has 12 months in 2020
# Station N°11081003 has 12 months in 2019
# Station N°11081003 has 12 months in 2018
# Station N°11081003 has 12 months in 2017
# Station N°11081003 has 12 months in 2016
# Station N°11081003 has 12 months in 2015
# Station N°11081003 has 12 months in 2014
# Station N°11081003 has 12 months in 2013
# Station N°11081003 has 12 months in 2012
# Station N°11081003 has 12 months in 2011
# Station N°11081003 has 12 months in 2010
# Station N°11081003 has 12 months in 2009
#
# Station N°11124003 has 12 months in 2022
# Station N°11124003 has 12 months in 2021
# Station N°11124003 has 12 months in 2020
# Station N°11124003 has 12 months in 2019
# Station N°11124003 has 12 months in 2018
# Station N°11124003 has 12 months in 2017
# Station N°11124003 has 12 months in 2016
# Station N°11124003 has 12 months in 2015
# Station N°11124003 has 12 months in 2014
# Station N°11124003 has 12 months in 2013
# Station N°11124003 has 12 months in 2012
# Station N°11124003 has 12 months in 2011
# Station N°11124003 has 12 months in 2010
# Station N°11124003 has 12 months in 2009
#
# Station N°11168001 has 12 months in 2022
# Station N°11168001 has 12 months in 2021
# Station N°11168001 has 12 months in 2020
# Station N°11168001 has 12 months in 2019
# Station N°11168001 has 12 months in 2018
# Station N°11168001 has 12 months in 2017
# Station N°11168001 has 12 months in 2016
# Station N°11168001 has 12 months in 2015
# Station N°11168001 has 12 months in 2014
# Station N°11168001 has 12 months in 2013
# Station N°11168001 has 12 months in 2012
# Station N°11168001 has 12 months in 2011
# Station N°11168001 has 12 months in 2010
# Station N°11168001 has 12 months in 2009
#
# Station N°11203004 has 12 months in 2022
# Station N°11203004 has 12 months in 2021
# Station N°11203004 has 12 months in 2020
# Station N°11203004 has 12 months in 2019
# Station N°11203004 has 12 months in 2018
# Station N°11203004 has 12 months in 2017
# Station N°11203004 has 12 months in 2016
# Station N°11203004 has 12 months in 2015
# Station N°11203004 has 12 months in 2014
# Station N°11203004 has 12 months in 2013
# Drop station N°11203004
# 1 manquants en 2012
#
#
# Station N°11203004 has 12 months in 2011
# Station N°11203004 has 12 months in 2010
# Station N°11203004 has 12 months in 2009
#
# Station N°11221004 has 12 months in 2022
# Station N°11221004 has 12 months in 2021
# Station N°11221004 has 12 months in 2020
# Station N°11221004 has 12 months in 2019
# Station N°11221004 has 12 months in 2018
# Station N°11221004 has 12 months in 2017
# Station N°11221004 has 12 months in 2016
# Station N°11221004 has 12 months in 2015
# Station N°11221004 has 12 months in 2014
# Station N°11221004 has 12 months in 2013
# Station N°11221004 has 12 months in 2012
# Station N°11221004 has 12 months in 2011
# Station N°11221004 has 12 months in 2010
# Station N°11221004 has 12 months in 2009
#
# Drop station N°11333001
# 11 manquants en 2022
#
#
# Station N°11333001 has 12 months in 2021
# Station N°11333001 has 12 months in 2020
# Station N°11333001 has 12 months in 2019
# Station N°11333001 has 12 months in 2018
# Station N°11333001 has 12 months in 2017
# Station N°11333001 has 12 months in 2016
# Station N°11333001 has 12 months in 2015
# Station N°11333001 has 12 months in 2014
# Station N°11333001 has 12 months in 2013
# Station N°11333001 has 12 months in 2012
# Station N°11333001 has 12 months in 2011
# Drop station N°11333001
# 5 manquants en 2010
#
#
# Drop station N°11333001
# 12 manquants en 2009
#
#
#
# Drop station N°11412001
# 10 manquants en 2022
#
#
# Station N°11412001 has 12 months in 2021
# Station N°11412001 has 12 months in 2020
# Station N°11412001 has 12 months in 2019
# Station N°11412001 has 12 months in 2018
# Drop station N°11412001
# 1 manquants en 2017
#
#
# Station N°11412001 has 12 months in 2016
# Station N°11412001 has 12 months in 2015
# Station N°11412001 has 12 months in 2014
# Station N°11412001 has 12 months in 2013
# Station N°11412001 has 12 months in 2012
# Drop station N°11412001
# 4 manquants en 2011
#
#
# Drop station N°11412001
# 12 manquants en 2010
#
#
# Drop station N°11412001
# 12 manquants en 2009
#
#
#
# Station N°12005001 has 12 months in 2022
# Station N°12005001 has 12 months in 2021
# Station N°12005001 has 12 months in 2020
# Station N°12005001 has 12 months in 2019
# Station N°12005001 has 12 months in 2018
# Station N°12005001 has 12 months in 2017
# Station N°12005001 has 12 months in 2016
# Drop station N°12005001
# 1 manquants en 2015
#
#
# Drop station N°12005001
# 4 manquants en 2014
#
#
# Drop station N°12005001
# 12 manquants en 2013
#
#
# Drop station N°12005001
# 12 manquants en 2012
#
#
# Drop station N°12005001
# 12 manquants en 2011
#
#
# Drop station N°12005001
# 12 manquants en 2010
#
#
# Drop station N°12005001
# 12 manquants en 2009
#
#
#
# Station N°12154003 has 12 months in 2022
# Station N°12154003 has 12 months in 2021
# Station N°12154003 has 12 months in 2020
# Station N°12154003 has 12 months in 2019
# Station N°12154003 has 12 months in 2018
# Station N°12154003 has 12 months in 2017
# Station N°12154003 has 12 months in 2016
# Station N°12154003 has 12 months in 2015
# Station N°12154003 has 12 months in 2014
# Station N°12154003 has 12 months in 2013
# Station N°12154003 has 12 months in 2012
# Station N°12154003 has 12 months in 2011
# Station N°12154003 has 12 months in 2010
# Station N°12154003 has 12 months in 2009
#
# Station N°12216001 has 12 months in 2022
# Station N°12216001 has 12 months in 2021
# Station N°12216001 has 12 months in 2020
# Station N°12216001 has 12 months in 2019
# Station N°12216001 has 12 months in 2018
# Station N°12216001 has 12 months in 2017
# Station N°12216001 has 12 months in 2016
# Station N°12216001 has 12 months in 2015
# Station N°12216001 has 12 months in 2014
# Station N°12216001 has 12 months in 2013
# Station N°12216001 has 12 months in 2012
# Station N°12216001 has 12 months in 2011
# Station N°12216001 has 12 months in 2010
# Station N°12216001 has 12 months in 2009
#
# Station N°12254001 has 12 months in 2022
# Station N°12254001 has 12 months in 2021
# Station N°12254001 has 12 months in 2020
# Station N°12254001 has 12 months in 2019
# Station N°12254001 has 12 months in 2018
# Station N°12254001 has 12 months in 2017
# Station N°12254001 has 12 months in 2016
# Station N°12254001 has 12 months in 2015
# Station N°12254001 has 12 months in 2014
# Station N°12254001 has 12 months in 2013
# Station N°12254001 has 12 months in 2012
# Station N°12254001 has 12 months in 2011
# Station N°12254001 has 12 months in 2010
# Station N°12254001 has 12 months in 2009
#
# Station N°12300004 has 12 months in 2022
# Station N°12300004 has 12 months in 2021
# Station N°12300004 has 12 months in 2020
# Station N°12300004 has 12 months in 2019
# Station N°12300004 has 12 months in 2018
# Station N°12300004 has 12 months in 2017
# Station N°12300004 has 12 months in 2016
# Station N°12300004 has 12 months in 2015
# Station N°12300004 has 12 months in 2014
# Station N°12300004 has 12 months in 2013
# Station N°12300004 has 12 months in 2012
# Station N°12300004 has 12 months in 2011
# Station N°12300004 has 12 months in 2010
# Station N°12300004 has 12 months in 2009
#
# Station N°13036003 has 12 months in 2022
# Station N°13036003 has 12 months in 2021
# Station N°13036003 has 12 months in 2020
# Station N°13036003 has 12 months in 2019
# Station N°13036003 has 12 months in 2018
# Station N°13036003 has 12 months in 2017
# Station N°13036003 has 12 months in 2016
# Station N°13036003 has 12 months in 2015
# Drop station N°13036003
# 10 manquants en 2014
#
#
# Drop station N°13036003
# 12 manquants en 2013
#
#
# Drop station N°13036003
# 12 manquants en 2012
#
#
# Drop station N°13036003
# 12 manquants en 2011
#
#
# Drop station N°13036003
# 12 manquants en 2010
#
#
# Drop station N°13036003
# 12 manquants en 2009
#
#
#
# Station N°13108004 has 12 months in 2022
# Station N°13108004 has 12 months in 2021
# Station N°13108004 has 12 months in 2020
# Station N°13108004 has 12 months in 2019
# Station N°13108004 has 12 months in 2018
# Station N°13108004 has 12 months in 2017
# Station N°13108004 has 12 months in 2016
# Station N°13108004 has 12 months in 2015
# Station N°13108004 has 12 months in 2014
# Station N°13108004 has 12 months in 2013
# Station N°13108004 has 12 months in 2012
# Station N°13108004 has 12 months in 2011
# Drop station N°13108004
# 6 manquants en 2010
#
#
# Drop station N°13108004
# 6 manquants en 2009
#
#
#
# Station N°14216001 has 12 months in 2022
# Station N°14216001 has 12 months in 2021
# Station N°14216001 has 12 months in 2020
# Station N°14216001 has 12 months in 2019
# Station N°14216001 has 12 months in 2018
# Station N°14216001 has 12 months in 2017
# Station N°14216001 has 12 months in 2016
# Station N°14216001 has 12 months in 2015
# Station N°14216001 has 12 months in 2014
# Station N°14216001 has 12 months in 2013
# Station N°14216001 has 12 months in 2012
# Station N°14216001 has 12 months in 2011
# Station N°14216001 has 12 months in 2010
# Station N°14216001 has 12 months in 2009
#
# Station N°15060002 has 12 months in 2022
# Station N°15060002 has 12 months in 2021
# Station N°15060002 has 12 months in 2020
# Station N°15060002 has 12 months in 2019
# Station N°15060002 has 12 months in 2018
# Station N°15060002 has 12 months in 2017
# Station N°15060002 has 12 months in 2016
# Station N°15060002 has 12 months in 2015
# Station N°15060002 has 12 months in 2014
# Station N°15060002 has 12 months in 2013
# Station N°15060002 has 12 months in 2012
# Station N°15060002 has 12 months in 2011
# Station N°15060002 has 12 months in 2010
# Station N°15060002 has 12 months in 2009
#
# Station N°15120005 has 12 months in 2022
# Station N°15120005 has 12 months in 2021
# Station N°15120005 has 12 months in 2020
# Station N°15120005 has 12 months in 2019
# Station N°15120005 has 12 months in 2018
# Station N°15120005 has 12 months in 2017
# Station N°15120005 has 12 months in 2016
# Station N°15120005 has 12 months in 2015
# Station N°15120005 has 12 months in 2014
# Station N°15120005 has 12 months in 2013
# Station N°15120005 has 12 months in 2012
# Station N°15120005 has 12 months in 2011
# Station N°15120005 has 12 months in 2010
# Station N°15120005 has 12 months in 2009
#
# Station N°15122002 has 12 months in 2022
# Station N°15122002 has 12 months in 2021
# Station N°15122002 has 12 months in 2020
# Station N°15122002 has 12 months in 2019
# Station N°15122002 has 12 months in 2018
# Station N°15122002 has 12 months in 2017
# Station N°15122002 has 12 months in 2016
# Station N°15122002 has 12 months in 2015
# Station N°15122002 has 12 months in 2014
# Station N°15122002 has 12 months in 2013
# Station N°15122002 has 12 months in 2012
# Station N°15122002 has 12 months in 2011
# Station N°15122002 has 12 months in 2010
# Station N°15122002 has 12 months in 2009
#
# Station N°16078001 has 12 months in 2022
# Station N°16078001 has 12 months in 2021
# Station N°16078001 has 12 months in 2020
# Station N°16078001 has 12 months in 2019
# Station N°16078001 has 12 months in 2018
# Station N°16078001 has 12 months in 2017
# Station N°16078001 has 12 months in 2016
# Station N°16078001 has 12 months in 2015
# Station N°16078001 has 12 months in 2014
# Station N°16078001 has 12 months in 2013
# Station N°16078001 has 12 months in 2012
# Station N°16078001 has 12 months in 2011
# Station N°16078001 has 12 months in 2010
# Drop station N°16078001
# 3 manquants en 2009
#
#
#
# Station N°16225001 has 12 months in 2022
# Station N°16225001 has 12 months in 2021
# Station N°16225001 has 12 months in 2020
# Station N°16225001 has 12 months in 2019
# Station N°16225001 has 12 months in 2018
# Station N°16225001 has 12 months in 2017
# Station N°16225001 has 12 months in 2016
# Station N°16225001 has 12 months in 2015
# Station N°16225001 has 12 months in 2014
# Station N°16225001 has 12 months in 2013
# Station N°16225001 has 12 months in 2012
# Station N°16225001 has 12 months in 2011
# Station N°16225001 has 12 months in 2010
# Station N°16225001 has 12 months in 2009
#
# Station N°16390001 has 12 months in 2022
# Station N°16390001 has 12 months in 2021
# Station N°16390001 has 12 months in 2020
# Station N°16390001 has 12 months in 2019
# Station N°16390001 has 12 months in 2018
# Station N°16390001 has 12 months in 2017
# Station N°16390001 has 12 months in 2016
# Station N°16390001 has 12 months in 2015
# Drop station N°16390001
# 6 manquants en 2014
#
#
# Station N°16390001 has 12 months in 2013
# Station N°16390001 has 12 months in 2012
# Station N°16390001 has 12 months in 2011
# Station N°16390001 has 12 months in 2010
# Station N°16390001 has 12 months in 2009
#
# Station N°17268002 has 12 months in 2022
# Station N°17268002 has 12 months in 2021
# Station N°17268002 has 12 months in 2020
# Station N°17268002 has 12 months in 2019
# Station N°17268002 has 12 months in 2018
# Station N°17268002 has 12 months in 2017
# Station N°17268002 has 12 months in 2016
# Station N°17268002 has 12 months in 2015
# Station N°17268002 has 12 months in 2014
# Station N°17268002 has 12 months in 2013
# Station N°17268002 has 12 months in 2012
# Station N°17268002 has 12 months in 2011
# Station N°17268002 has 12 months in 2010
# Station N°17268002 has 12 months in 2009
#
# Station N°18015003 has 12 months in 2022
# Station N°18015003 has 12 months in 2021
# Station N°18015003 has 12 months in 2020
# Station N°18015003 has 12 months in 2019
# Station N°18015003 has 12 months in 2018
# Station N°18015003 has 12 months in 2017
# Station N°18015003 has 12 months in 2016
# Station N°18015003 has 12 months in 2015
# Station N°18015003 has 12 months in 2014
# Station N°18015003 has 12 months in 2013
# Station N°18015003 has 12 months in 2012
# Station N°18015003 has 12 months in 2011
# Station N°18015003 has 12 months in 2010
# Station N°18015003 has 12 months in 2009
#
# Station N°18033001 has 12 months in 2022
# Station N°18033001 has 12 months in 2021
# Station N°18033001 has 12 months in 2020
# Station N°18033001 has 12 months in 2019
# Station N°18033001 has 12 months in 2018
# Station N°18033001 has 12 months in 2017
# Station N°18033001 has 12 months in 2016
# Station N°18033001 has 12 months in 2015
# Station N°18033001 has 12 months in 2014
# Station N°18033001 has 12 months in 2013
# Station N°18033001 has 12 months in 2012
# Station N°18033001 has 12 months in 2011
# Station N°18033001 has 12 months in 2010
# Drop station N°18033001
# 1 manquants en 2009
#
#
#
# Station N°18125004 has 12 months in 2022
# Station N°18125004 has 12 months in 2021
# Station N°18125004 has 12 months in 2020
# Station N°18125004 has 12 months in 2019
# Station N°18125004 has 12 months in 2018
# Station N°18125004 has 12 months in 2017
# Station N°18125004 has 12 months in 2016
# Station N°18125004 has 12 months in 2015
# Station N°18125004 has 12 months in 2014
# Station N°18125004 has 12 months in 2013
# Station N°18125004 has 12 months in 2012
# Station N°18125004 has 12 months in 2011
# Station N°18125004 has 12 months in 2010
# Station N°18125004 has 12 months in 2009
#
# Station N°18172003 has 12 months in 2022
# Station N°18172003 has 12 months in 2021
# Station N°18172003 has 12 months in 2020
# Station N°18172003 has 12 months in 2019
# Station N°18172003 has 12 months in 2018
# Station N°18172003 has 12 months in 2017
# Station N°18172003 has 12 months in 2016
# Station N°18172003 has 12 months in 2015
# Station N°18172003 has 12 months in 2014
# Station N°18172003 has 12 months in 2013
# Station N°18172003 has 12 months in 2012
# Station N°18172003 has 12 months in 2011
# Station N°18172003 has 12 months in 2010
# Station N°18172003 has 12 months in 2009
#
# Station N°18175003 has 12 months in 2022
# Station N°18175003 has 12 months in 2021
# Station N°18175003 has 12 months in 2020
# Station N°18175003 has 12 months in 2019
# Station N°18175003 has 12 months in 2018
# Station N°18175003 has 12 months in 2017
# Station N°18175003 has 12 months in 2016
# Station N°18175003 has 12 months in 2015
# Station N°18175003 has 12 months in 2014
# Station N°18175003 has 12 months in 2013
# Station N°18175003 has 12 months in 2012
# Station N°18175003 has 12 months in 2011
# Station N°18175003 has 12 months in 2010
# Station N°18175003 has 12 months in 2009
#
# Station N°19010001 has 12 months in 2022
# Station N°19010001 has 12 months in 2021
# Station N°19010001 has 12 months in 2020
# Station N°19010001 has 12 months in 2019
# Station N°19010001 has 12 months in 2018
# Station N°19010001 has 12 months in 2017
# Station N°19010001 has 12 months in 2016
# Station N°19010001 has 12 months in 2015
# Station N°19010001 has 12 months in 2014
# Station N°19010001 has 12 months in 2013
# Station N°19010001 has 12 months in 2012
# Station N°19010001 has 12 months in 2011
# Station N°19010001 has 12 months in 2010
# Station N°19010001 has 12 months in 2009
#
# Station N°19073006 has 12 months in 2022
# Station N°19073006 has 12 months in 2021
# Station N°19073006 has 12 months in 2020
# Station N°19073006 has 12 months in 2019
# Station N°19073006 has 12 months in 2018
# Drop station N°19073006
# 6 manquants en 2017
#
#
# Drop station N°19073006
# 12 manquants en 2016
#
#
# Drop station N°19073006
# 12 manquants en 2015
#
#
# Drop station N°19073006
# 12 manquants en 2014
#
#
# Drop station N°19073006
# 12 manquants en 2013
#
#
# Drop station N°19073006
# 12 manquants en 2012
#
#
# Drop station N°19073006
# 12 manquants en 2011
#
#
# Drop station N°19073006
# 12 manquants en 2010
#
#
# Drop station N°19073006
# 12 manquants en 2009
#
#
#
# Drop station N°20007402
# 5 manquants en 2022
#
#
# Drop station N°20007402
# 1 manquants en 2021
#
#
# Station N°20007402 has 12 months in 2020
# Station N°20007402 has 12 months in 2019
# Station N°20007402 has 12 months in 2018
# Station N°20007402 has 12 months in 2017
# Station N°20007402 has 12 months in 2016
# Station N°20007402 has 12 months in 2015
# Station N°20007402 has 12 months in 2014
# Station N°20007402 has 12 months in 2013
# Station N°20007402 has 12 months in 2012
# Station N°20007402 has 12 months in 2011
# Station N°20007402 has 12 months in 2010
# Station N°20007402 has 12 months in 2009
#
# Station N°20041001 has 12 months in 2022
# Station N°20041001 has 12 months in 2021
# Station N°20041001 has 12 months in 2020
# Station N°20041001 has 12 months in 2019
# Station N°20041001 has 12 months in 2018
# Station N°20041001 has 12 months in 2017
# Station N°20041001 has 12 months in 2016
# Station N°20041001 has 12 months in 2015
# Station N°20041001 has 12 months in 2014
# Station N°20041001 has 12 months in 2013
# Station N°20041001 has 12 months in 2012
# Station N°20041001 has 12 months in 2011
# Station N°20041001 has 12 months in 2010
# Station N°20041001 has 12 months in 2009
#
# Station N°20046002 has 12 months in 2022
# Station N°20046002 has 12 months in 2021
# Station N°20046002 has 12 months in 2020
# Station N°20046002 has 12 months in 2019
# Drop station N°20046002
# 5 manquants en 2018
#
#
# Drop station N°20046002
# 12 manquants en 2017
#
#
# Drop station N°20046002
# 12 manquants en 2016
#
#
# Drop station N°20046002
# 12 manquants en 2015
#
#
# Drop station N°20046002
# 12 manquants en 2014
#
#
# Drop station N°20046002
# 12 manquants en 2013
#
#
# Drop station N°20046002
# 12 manquants en 2012
#
#
# Drop station N°20046002
# 12 manquants en 2011
#
#
# Drop station N°20046002
# 12 manquants en 2010
#
#
# Drop station N°20046002
# 12 manquants en 2009
#
#
#
# Station N°20047006 has 12 months in 2022
# Station N°20047006 has 12 months in 2021
# Station N°20047006 has 12 months in 2020
# Station N°20047006 has 12 months in 2019
# Station N°20047006 has 12 months in 2018
# Station N°20047006 has 12 months in 2017
# Drop station N°20047006
# 5 manquants en 2016
#
#
# Drop station N°20047006
# 12 manquants en 2015
#
#
# Drop station N°20047006
# 12 manquants en 2014
#
#
# Drop station N°20047006
# 12 manquants en 2013
#
#
# Drop station N°20047006
# 12 manquants en 2012
#
#
# Drop station N°20047006
# 12 manquants en 2011
#
#
# Drop station N°20047006
# 12 manquants en 2010
#
#
# Drop station N°20047006
# 12 manquants en 2009
#
#
#
# Station N°20093002 has 12 months in 2022
# Station N°20093002 has 12 months in 2021
# Station N°20093002 has 12 months in 2020
# Station N°20093002 has 12 months in 2019
# Station N°20093002 has 12 months in 2018
# Station N°20093002 has 12 months in 2017
# Station N°20093002 has 12 months in 2016
# Station N°20093002 has 12 months in 2015
# Station N°20093002 has 12 months in 2014
# Station N°20093002 has 12 months in 2013
# Station N°20093002 has 12 months in 2012
# Station N°20093002 has 12 months in 2011
# Station N°20093002 has 12 months in 2010
# Station N°20093002 has 12 months in 2009
#
# Station N°20096008 has 12 months in 2022
# Station N°20096008 has 12 months in 2021
# Station N°20096008 has 12 months in 2020
# Station N°20096008 has 12 months in 2019
# Station N°20096008 has 12 months in 2018
# Station N°20096008 has 12 months in 2017
# Station N°20096008 has 12 months in 2016
# Drop station N°20096008
# 9 manquants en 2015
#
#
# Drop station N°20096008
# 12 manquants en 2014
#
#
# Drop station N°20096008
# 12 manquants en 2013
#
#
# Drop station N°20096008
# 12 manquants en 2012
#
#
# Drop station N°20096008
# 12 manquants en 2011
#
#
# Drop station N°20096008
# 12 manquants en 2010
#
#
# Drop station N°20096008
# 12 manquants en 2009
#
#
#
# Station N°20114002 has 12 months in 2022
# Station N°20114002 has 12 months in 2021
# Station N°20114002 has 12 months in 2020
# Station N°20114002 has 12 months in 2019
# Station N°20114002 has 12 months in 2018
# Station N°20114002 has 12 months in 2017
# Station N°20114002 has 12 months in 2016
# Station N°20114002 has 12 months in 2015
# Station N°20114002 has 12 months in 2014
# Station N°20114002 has 12 months in 2013
# Station N°20114002 has 12 months in 2012
# Station N°20114002 has 12 months in 2011
# Station N°20114002 has 12 months in 2010
# Station N°20114002 has 12 months in 2009
#
# Station N°20154001 has 12 months in 2022
# Station N°20154001 has 12 months in 2021
# Station N°20154001 has 12 months in 2020
# Station N°20154001 has 12 months in 2019
# Station N°20154001 has 12 months in 2018
# Station N°20154001 has 12 months in 2017
# Station N°20154001 has 12 months in 2016
# Station N°20154001 has 12 months in 2015
# Station N°20154001 has 12 months in 2014
# Station N°20154001 has 12 months in 2013
# Station N°20154001 has 12 months in 2012
# Station N°20154001 has 12 months in 2011
# Station N°20154001 has 12 months in 2010
# Drop station N°20154001
# 1 manquants en 2009
#
#
#
# Station N°20160001 has 12 months in 2022
# Station N°20160001 has 12 months in 2021
# Station N°20160001 has 12 months in 2020
# Drop station N°20160001
# 1 manquants en 2019
#
#
# Drop station N°20160001
# 12 manquants en 2018
#
#
# Drop station N°20160001
# 12 manquants en 2017
#
#
# Drop station N°20160001
# 12 manquants en 2016
#
#
# Drop station N°20160001
# 12 manquants en 2015
#
#
# Drop station N°20160001
# 12 manquants en 2014
#
#
# Drop station N°20160001
# 12 manquants en 2013
#
#
# Drop station N°20160001
# 12 manquants en 2012
#
#
# Drop station N°20160001
# 12 manquants en 2011
#
#
# Drop station N°20160001
# 12 manquants en 2010
#
#
# Drop station N°20160001
# 12 manquants en 2009
#
#
#
# Station N°20185003 has 12 months in 2022
# Station N°20185003 has 12 months in 2021
# Station N°20185003 has 12 months in 2020
# Station N°20185003 has 12 months in 2019
# Station N°20185003 has 12 months in 2018
# Station N°20185003 has 12 months in 2017
# Station N°20185003 has 12 months in 2016
# Station N°20185003 has 12 months in 2015
# Station N°20185003 has 12 months in 2014
# Station N°20185003 has 12 months in 2013
# Station N°20185003 has 12 months in 2012
# Station N°20185003 has 12 months in 2011
# Station N°20185003 has 12 months in 2010
# Station N°20185003 has 12 months in 2009
#
# Station N°20223001 has 12 months in 2022
# Station N°20223001 has 12 months in 2021
# Station N°20223001 has 12 months in 2020
# Station N°20223001 has 12 months in 2019
# Station N°20223001 has 12 months in 2018
# Station N°20223001 has 12 months in 2017
# Station N°20223001 has 12 months in 2016
# Station N°20223001 has 12 months in 2015
# Station N°20223001 has 12 months in 2014
# Station N°20223001 has 12 months in 2013
# Station N°20223001 has 12 months in 2012
# Station N°20223001 has 12 months in 2011
# Station N°20223001 has 12 months in 2010
# Station N°20223001 has 12 months in 2009
#
# Station N°20232002 has 12 months in 2022
# Station N°20232002 has 12 months in 2021
# Station N°20232002 has 12 months in 2020
# Station N°20232002 has 12 months in 2019
# Station N°20232002 has 12 months in 2018
# Station N°20232002 has 12 months in 2017
# Station N°20232002 has 12 months in 2016
# Station N°20232002 has 12 months in 2015
# Station N°20232002 has 12 months in 2014
# Station N°20232002 has 12 months in 2013
# Station N°20232002 has 12 months in 2012
# Station N°20232002 has 12 months in 2011
# Station N°20232002 has 12 months in 2010
# Station N°20232002 has 12 months in 2009
#
# Station N°20254006 has 12 months in 2022
# Station N°20254006 has 12 months in 2021
# Station N°20254006 has 12 months in 2020
# Station N°20254006 has 12 months in 2019
# Station N°20254006 has 12 months in 2018
# Station N°20254006 has 12 months in 2017
# Station N°20254006 has 12 months in 2016
# Station N°20254006 has 12 months in 2015
# Station N°20254006 has 12 months in 2014
# Station N°20254006 has 12 months in 2013
# Station N°20254006 has 12 months in 2012
# Station N°20254006 has 12 months in 2011
# Station N°20254006 has 12 months in 2010
# Drop station N°20254006
# 3 manquants en 2009
#
#
#
# Station N°20258001 has 12 months in 2022
# Station N°20258001 has 12 months in 2021
# Station N°20258001 has 12 months in 2020
# Station N°20258001 has 12 months in 2019
# Station N°20258001 has 12 months in 2018
# Station N°20258001 has 12 months in 2017
# Station N°20258001 has 12 months in 2016
# Station N°20258001 has 12 months in 2015
# Station N°20258001 has 12 months in 2014
# Station N°20258001 has 12 months in 2013
# Station N°20258001 has 12 months in 2012
# Station N°20258001 has 12 months in 2011
# Station N°20258001 has 12 months in 2010
# Station N°20258001 has 12 months in 2009
#
# Station N°20268001 has 12 months in 2022
# Station N°20268001 has 12 months in 2021
# Station N°20268001 has 12 months in 2020
# Station N°20268001 has 12 months in 2019
# Station N°20268001 has 12 months in 2018
# Station N°20268001 has 12 months in 2017
# Station N°20268001 has 12 months in 2016
# Station N°20268001 has 12 months in 2015
# Station N°20268001 has 12 months in 2014
# Station N°20268001 has 12 months in 2013
# Station N°20268001 has 12 months in 2012
# Station N°20268001 has 12 months in 2011
# Station N°20268001 has 12 months in 2010
# Station N°20268001 has 12 months in 2009
#
# Station N°20270001 has 12 months in 2022
# Station N°20270001 has 12 months in 2021
# Station N°20270001 has 12 months in 2020
# Station N°20270001 has 12 months in 2019
# Station N°20270001 has 12 months in 2018
# Station N°20270001 has 12 months in 2017
# Station N°20270001 has 12 months in 2016
# Station N°20270001 has 12 months in 2015
# Station N°20270001 has 12 months in 2014
# Station N°20270001 has 12 months in 2013
# Station N°20270001 has 12 months in 2012
# Station N°20270001 has 12 months in 2011
# Station N°20270001 has 12 months in 2010
# Drop station N°20270001
# 1 manquants en 2009
#
#
#
# Station N°20272004 has 12 months in 2022
# Station N°20272004 has 12 months in 2021
# Station N°20272004 has 12 months in 2020
# Station N°20272004 has 12 months in 2019
# Station N°20272004 has 12 months in 2018
# ...
# Station N°81292001 has 12 months in 2017
# Station N°81292001 has 12 months in 2016
# Station N°81292001 has 12 months in 2015
# Station N°81292001 has 12 months in 2014
# Station N°81292001 has 12 months in 2013
# Station N°81292001 has 12 months in 2012
# Station N°81292001 has 12 months in 2011
# Station N°81292001 has 12 months in 2010
# Station N°81292001 has 12 months in 2009
#
# Station N°82038006 has 12 months in 2022
# Station N°82038006 has 12 months in 2021
# Station N°82038006 has 12 months in 2020
# Station N°82038006 has 12 months in 2019
# Station N°82038006 has 12 months in 2018
# Station N°82038006 has 12 months in 2017
# Station N°82038006 has 12 months in 2016
# Station N°82038006 has 12 months in 2015
# Station N°82038006 has 12 months in 2014
# Station N°82038006 has 12 months in 2013
# Station N°82038006 has 12 months in 2012
# Station N°82038006 has 12 months in 2011
# Station N°82038006 has 12 months in 2010
# Station N°82038006 has 12 months in 2009
#
# Station N°82094004 has 12 months in 2022
# Station N°82094004 has 12 months in 2021
# Station N°82094004 has 12 months in 2020
# Station N°82094004 has 12 months in 2019
# Station N°82094004 has 12 months in 2018
# Station N°82094004 has 12 months in 2017
# Station N°82094004 has 12 months in 2016
# Station N°82094004 has 12 months in 2015
# Station N°82094004 has 12 months in 2014
# Station N°82094004 has 12 months in 2013
# Station N°82094004 has 12 months in 2012
# Station N°82094004 has 12 months in 2011
# Station N°82094004 has 12 months in 2010
# Station N°82094004 has 12 months in 2009
#
# Station N°85060002 has 12 months in 2022
# Station N°85060002 has 12 months in 2021
# Station N°85060002 has 12 months in 2020
# Station N°85060002 has 12 months in 2019
# Station N°85060002 has 12 months in 2018
# Station N°85060002 has 12 months in 2017
# Station N°85060002 has 12 months in 2016
# Station N°85060002 has 12 months in 2015
# Station N°85060002 has 12 months in 2014
# Station N°85060002 has 12 months in 2013
# Station N°85060002 has 12 months in 2012
# Station N°85060002 has 12 months in 2011
# Station N°85060002 has 12 months in 2010
# Station N°85060002 has 12 months in 2009
#
# Station N°85092004 has 12 months in 2022
# Station N°85092004 has 12 months in 2021
# Station N°85092004 has 12 months in 2020
# Station N°85092004 has 12 months in 2019
# Station N°85092004 has 12 months in 2018
# Station N°85092004 has 12 months in 2017
# Station N°85092004 has 12 months in 2016
# Station N°85092004 has 12 months in 2015
# Station N°85092004 has 12 months in 2014
# Station N°85092004 has 12 months in 2013
# Station N°85092004 has 12 months in 2012
# Station N°85092004 has 12 months in 2011
# Station N°85092004 has 12 months in 2010
# Station N°85092004 has 12 months in 2009
#
# Station N°85169002 has 12 months in 2022
# Station N°85169002 has 12 months in 2021
# Station N°85169002 has 12 months in 2020
# Station N°85169002 has 12 months in 2019
# Station N°85169002 has 12 months in 2018
# Station N°85169002 has 12 months in 2017
# Station N°85169002 has 12 months in 2016
# Station N°85169002 has 12 months in 2015
# Station N°85169002 has 12 months in 2014
# Station N°85169002 has 12 months in 2013
# Station N°85169002 has 12 months in 2012
# Station N°85169002 has 12 months in 2011
# Station N°85169002 has 12 months in 2010
# Station N°85169002 has 12 months in 2009
#
# Station N°85182004 has 12 months in 2022
# Station N°85182004 has 12 months in 2021
# Station N°85182004 has 12 months in 2020
# Station N°85182004 has 12 months in 2019
# Station N°85182004 has 12 months in 2018
# Station N°85182004 has 12 months in 2017
# Station N°85182004 has 12 months in 2016
# Station N°85182004 has 12 months in 2015
# Station N°85182004 has 12 months in 2014
# Station N°85182004 has 12 months in 2013
# Station N°85182004 has 12 months in 2012
# Station N°85182004 has 12 months in 2011
# Station N°85182004 has 12 months in 2010
# Station N°85182004 has 12 months in 2009
#
# Station N°85216001 has 12 months in 2022
# Station N°85216001 has 12 months in 2021
# Station N°85216001 has 12 months in 2020
# Station N°85216001 has 12 months in 2019
# Station N°85216001 has 12 months in 2018
# Drop station N°85216001
# 1 manquants en 2017
#
#
# Station N°85216001 has 12 months in 2016
# Station N°85216001 has 12 months in 2015
# Station N°85216001 has 12 months in 2014
# Station N°85216001 has 12 months in 2013
# Station N°85216001 has 12 months in 2012
# Station N°85216001 has 12 months in 2011
# Station N°85216001 has 12 months in 2010
# Station N°85216001 has 12 months in 2009
#
# Station N°86009001 has 12 months in 2022
# Station N°86009001 has 12 months in 2021
# Station N°86009001 has 12 months in 2020
# Station N°86009001 has 12 months in 2019
# Station N°86009001 has 12 months in 2018
# Station N°86009001 has 12 months in 2017
# Station N°86009001 has 12 months in 2016
# Drop station N°86009001
# 9 manquants en 2015
#
#
# Drop station N°86009001
# 12 manquants en 2014
#
#
# Drop station N°86009001
# 12 manquants en 2013
#
#
# Drop station N°86009001
# 12 manquants en 2012
#
#
# Drop station N°86009001
# 12 manquants en 2011
#
#
# Drop station N°86009001
# 7 manquants en 2010
#
#
# Station N°86009001 has 12 months in 2009
#
# Station N°86027001 has 12 months in 2022
# Station N°86027001 has 12 months in 2021
# Station N°86027001 has 12 months in 2020
# Station N°86027001 has 12 months in 2019
# Station N°86027001 has 12 months in 2018
# Station N°86027001 has 12 months in 2017
# Station N°86027001 has 12 months in 2016
# Station N°86027001 has 12 months in 2015
# Station N°86027001 has 12 months in 2014
# Station N°86027001 has 12 months in 2013
# Station N°86027001 has 12 months in 2012
# Station N°86027001 has 12 months in 2011
# Station N°86027001 has 12 months in 2010
# Station N°86027001 has 12 months in 2009
#
# Station N°86078002 has 12 months in 2022
# Station N°86078002 has 12 months in 2021
# Station N°86078002 has 12 months in 2020
# Station N°86078002 has 12 months in 2019
# Station N°86078002 has 12 months in 2018
# Station N°86078002 has 12 months in 2017
# Station N°86078002 has 12 months in 2016
# Station N°86078002 has 12 months in 2015
# Station N°86078002 has 12 months in 2014
# Station N°86078002 has 12 months in 2013
# Station N°86078002 has 12 months in 2012
# Station N°86078002 has 12 months in 2011
# Station N°86078002 has 12 months in 2010
# Station N°86078002 has 12 months in 2009
#
# Station N°86137003 has 12 months in 2022
# Station N°86137003 has 12 months in 2021
# Station N°86137003 has 12 months in 2020
# Station N°86137003 has 12 months in 2019
# Station N°86137003 has 12 months in 2018
# Station N°86137003 has 12 months in 2017
# Station N°86137003 has 12 months in 2016
# Station N°86137003 has 12 months in 2015
# Station N°86137003 has 12 months in 2014
# Station N°86137003 has 12 months in 2013
# Station N°86137003 has 12 months in 2012
# Station N°86137003 has 12 months in 2011
# Station N°86137003 has 12 months in 2010
# Station N°86137003 has 12 months in 2009
#
# Station N°86165005 has 12 months in 2022
# Station N°86165005 has 12 months in 2021
# Station N°86165005 has 12 months in 2020
# Station N°86165005 has 12 months in 2019
# Station N°86165005 has 12 months in 2018
# Station N°86165005 has 12 months in 2017
# Station N°86165005 has 12 months in 2016
# Station N°86165005 has 12 months in 2015
# Station N°86165005 has 12 months in 2014
# Station N°86165005 has 12 months in 2013
# Station N°86165005 has 12 months in 2012
# Station N°86165005 has 12 months in 2011
# Station N°86165005 has 12 months in 2010
# Station N°86165005 has 12 months in 2009
#
# Station N°87089003 has 12 months in 2022
# Station N°87089003 has 12 months in 2021
# Station N°87089003 has 12 months in 2020
# Station N°87089003 has 12 months in 2019
# Station N°87089003 has 12 months in 2018
# Station N°87089003 has 12 months in 2017
# Station N°87089003 has 12 months in 2016
# Station N°87089003 has 12 months in 2015
# Station N°87089003 has 12 months in 2014
# Station N°87089003 has 12 months in 2013
# Station N°87089003 has 12 months in 2012
# Station N°87089003 has 12 months in 2011
# Station N°87089003 has 12 months in 2010
# Station N°87089003 has 12 months in 2009
#
# Station N°87154003 has 12 months in 2022
# Station N°87154003 has 12 months in 2021
# Station N°87154003 has 12 months in 2020
# Station N°87154003 has 12 months in 2019
# Station N°87154003 has 12 months in 2018
# Station N°87154003 has 12 months in 2017
# Station N°87154003 has 12 months in 2016
# Station N°87154003 has 12 months in 2015
# Station N°87154003 has 12 months in 2014
# Station N°87154003 has 12 months in 2013
# Station N°87154003 has 12 months in 2012
# Station N°87154003 has 12 months in 2011
# Station N°87154003 has 12 months in 2010
# Station N°87154003 has 12 months in 2009
#
# Station N°88136001 has 12 months in 2022
# Station N°88136001 has 12 months in 2021
# Station N°88136001 has 12 months in 2020
# Station N°88136001 has 12 months in 2019
# Station N°88136001 has 12 months in 2018
# Station N°88136001 has 12 months in 2017
# Station N°88136001 has 12 months in 2016
# Station N°88136001 has 12 months in 2015
# Station N°88136001 has 12 months in 2014
# Station N°88136001 has 12 months in 2013
# Station N°88136001 has 12 months in 2012
# Station N°88136001 has 12 months in 2011
# Drop station N°88136001
# 5 manquants en 2010
#
#
# Drop station N°88136001
# 2 manquants en 2009
#
#
#
# Station N°88271001 has 12 months in 2022
# Station N°88271001 has 12 months in 2021
# Station N°88271001 has 12 months in 2020
# Station N°88271001 has 12 months in 2019
# Station N°88271001 has 12 months in 2018
# Station N°88271001 has 12 months in 2017
# Station N°88271001 has 12 months in 2016
# Station N°88271001 has 12 months in 2015
# Station N°88271001 has 12 months in 2014
# Station N°88271001 has 12 months in 2013
# Station N°88271001 has 12 months in 2012
# Station N°88271001 has 12 months in 2011
# Station N°88271001 has 12 months in 2010
# Station N°88271001 has 12 months in 2009
#
# Station N°88393003 has 12 months in 2022
# Station N°88393003 has 12 months in 2021
# Station N°88393003 has 12 months in 2020
# Station N°88393003 has 12 months in 2019
# Station N°88393003 has 12 months in 2018
# Station N°88393003 has 12 months in 2017
# Station N°88393003 has 12 months in 2016
# Station N°88393003 has 12 months in 2015
# Station N°88393003 has 12 months in 2014
# Station N°88393003 has 12 months in 2013
# Station N°88393003 has 12 months in 2012
# Station N°88393003 has 12 months in 2011
# Station N°88393003 has 12 months in 2010
# Station N°88393003 has 12 months in 2009
#
# Station N°88402002 has 12 months in 2022
# Station N°88402002 has 12 months in 2021
# Station N°88402002 has 12 months in 2020
# Station N°88402002 has 12 months in 2019
# Station N°88402002 has 12 months in 2018
# Station N°88402002 has 12 months in 2017
# Station N°88402002 has 12 months in 2016
# Station N°88402002 has 12 months in 2015
# Station N°88402002 has 12 months in 2014
# Station N°88402002 has 12 months in 2013
# Station N°88402002 has 12 months in 2012
# Station N°88402002 has 12 months in 2011
# Station N°88402002 has 12 months in 2010
# Station N°88402002 has 12 months in 2009
#
# Station N°89295001 has 12 months in 2022
# Station N°89295001 has 12 months in 2021
# Station N°89295001 has 12 months in 2020
# Station N°89295001 has 12 months in 2019
# Station N°89295001 has 12 months in 2018
# Station N°89295001 has 12 months in 2017
# Station N°89295001 has 12 months in 2016
# Station N°89295001 has 12 months in 2015
# Station N°89295001 has 12 months in 2014
# Drop station N°89295001
# 3 manquants en 2013
#
#
# Drop station N°89295001
# 12 manquants en 2012
#
#
# Drop station N°89295001
# 12 manquants en 2011
#
#
# Drop station N°89295001
# 12 manquants en 2010
#
#
# Drop station N°89295001
# 12 manquants en 2009
#
#
#
# Station N°89333001 has 12 months in 2022
# Station N°89333001 has 12 months in 2021
# Station N°89333001 has 12 months in 2020
# Station N°89333001 has 12 months in 2019
# Station N°89333001 has 12 months in 2018
# Station N°89333001 has 12 months in 2017
# Station N°89333001 has 12 months in 2016
# Station N°89333001 has 12 months in 2015
# Station N°89333001 has 12 months in 2014
# Station N°89333001 has 12 months in 2013
# Station N°89333001 has 12 months in 2012
# Station N°89333001 has 12 months in 2011
# Station N°89333001 has 12 months in 2010
# Station N°89333001 has 12 months in 2009
#
# Station N°89365001 has 12 months in 2022
# Station N°89365001 has 12 months in 2021
# Station N°89365001 has 12 months in 2020
# Station N°89365001 has 12 months in 2019
# Station N°89365001 has 12 months in 2018
# Station N°89365001 has 12 months in 2017
# Station N°89365001 has 12 months in 2016
# Station N°89365001 has 12 months in 2015
# Station N°89365001 has 12 months in 2014
# Station N°89365001 has 12 months in 2013
# Station N°89365001 has 12 months in 2012
# Station N°89365001 has 12 months in 2011
# Station N°89365001 has 12 months in 2010
# Station N°89365001 has 12 months in 2009
#
# Station N°89380001 has 12 months in 2022
# Station N°89380001 has 12 months in 2021
# Station N°89380001 has 12 months in 2020
# Station N°89380001 has 12 months in 2019
# Station N°89380001 has 12 months in 2018
# Station N°89380001 has 12 months in 2017
# Station N°89380001 has 12 months in 2016
# Station N°89380001 has 12 months in 2015
# Station N°89380001 has 12 months in 2014
# Station N°89380001 has 12 months in 2013
# Station N°89380001 has 12 months in 2012
# Station N°89380001 has 12 months in 2011
# Station N°89380001 has 12 months in 2010
# Station N°89380001 has 12 months in 2009
#
# Station N°89387002 has 12 months in 2022
# Station N°89387002 has 12 months in 2021
# Station N°89387002 has 12 months in 2020
# Station N°89387002 has 12 months in 2019
# Station N°89387002 has 12 months in 2018
# Station N°89387002 has 12 months in 2017
# Station N°89387002 has 12 months in 2016
# Station N°89387002 has 12 months in 2015
# Station N°89387002 has 12 months in 2014
# Station N°89387002 has 12 months in 2013
# Station N°89387002 has 12 months in 2012
# Station N°89387002 has 12 months in 2011
# Station N°89387002 has 12 months in 2010
# Station N°89387002 has 12 months in 2009
#
# Station N°89418007 has 12 months in 2022
# Station N°89418007 has 12 months in 2021
# Station N°89418007 has 12 months in 2020
# Station N°89418007 has 12 months in 2019
# Station N°89418007 has 12 months in 2018
# Station N°89418007 has 12 months in 2017
# Station N°89418007 has 12 months in 2016
# Station N°89418007 has 12 months in 2015
# Station N°89418007 has 12 months in 2014
# Station N°89418007 has 12 months in 2013
# Station N°89418007 has 12 months in 2012
# Station N°89418007 has 12 months in 2011
# Station N°89418007 has 12 months in 2010
# Station N°89418007 has 12 months in 2009
#
# Station N°90035001 has 12 months in 2022
# Station N°90035001 has 12 months in 2021
# Station N°90035001 has 12 months in 2020
# Station N°90035001 has 12 months in 2019
# Station N°90035001 has 12 months in 2018
# Station N°90035001 has 12 months in 2017
# Station N°90035001 has 12 months in 2016
# Station N°90035001 has 12 months in 2015
# Station N°90035001 has 12 months in 2014
# Station N°90035001 has 12 months in 2013
# Station N°90035001 has 12 months in 2012
# Station N°90035001 has 12 months in 2011
# Station N°90035001 has 12 months in 2010
# Drop station N°90035001
# 4 manquants en 2009
#
#
#
# Station N°91184001 has 12 months in 2022
# Station N°91184001 has 12 months in 2021
# Station N°91184001 has 12 months in 2020
# Station N°91184001 has 12 months in 2019
# Station N°91184001 has 12 months in 2018
# Station N°91184001 has 12 months in 2017
# Station N°91184001 has 12 months in 2016
# Station N°91184001 has 12 months in 2015
# Station N°91184001 has 12 months in 2014
# Station N°91184001 has 12 months in 2013
# Station N°91184001 has 12 months in 2012
# Station N°91184001 has 12 months in 2011
# Station N°91184001 has 12 months in 2010
# Station N°91184001 has 12 months in 2009
#
# Station N°91200002 has 12 months in 2022
# Station N°91200002 has 12 months in 2021
# Station N°91200002 has 12 months in 2020
# Station N°91200002 has 12 months in 2019
# Station N°91200002 has 12 months in 2018
# Station N°91200002 has 12 months in 2017
# Station N°91200002 has 12 months in 2016
# Station N°91200002 has 12 months in 2015
# Station N°91200002 has 12 months in 2014
# Station N°91200002 has 12 months in 2013
# Station N°91200002 has 12 months in 2012
# Station N°91200002 has 12 months in 2011
# Station N°91200002 has 12 months in 2010
# Station N°91200002 has 12 months in 2009

# %%
# gestion des outliers sur la target ?

# %%
df_recent = df_recent[~df_recent["NUM_POSTE"].isin(to_drop)]

# %%
# 203 stations qui ont au moins 14 années de continuité (12 mois complets) à partir de 2022
print(len(df_recent.groupby(["NUM_POSTE"]).max()))
# Out:
# 203

# %%
# PREPROCESSING DATE

df_recent["AAAAMM"] = pd.to_datetime(df_recent["AAAAMM"])

def last_day_of_month(aaaamm):
    """
    prend une date format AAAAMM et retourne une string format AAAA-MM-DD avec DD = dernier jour du mois
    """
    year = aaaamm.year
    month = aaaamm.month
    last_day = monthrange(year, month)[1]
    return f"{year}-{month:02d}-{last_day:02d}"

df_recent["date"] = df_recent["AAAAMM"].apply(last_day_of_month)
df_recent["date"] = pd.to_datetime(df_recent["date"])

# %%
to_keep = ["NUM_POSTE","NOM_USUEL","LAT","LON","ALTI","Year","Month","vent_speed_inst_moy_mensu","departement_num","departement_name","region","date"]
to_drop = [col for col in df if col not in to_keep]

# %%
df_recent = df_recent.drop(to_drop,axis=1)

# %%
def clean_continuity(dataframe):

    """
    INPUT = un dataframe
    --> parcours la série d'année en année en commençant par la plus récente
    --> si année en cours < 12 mois, drop l'année et toutes les années antérieures
    --> si "trou" entre année en cours N et année suivante, drop N-1 et toutes les années antérieures 
    --> transforme en série temporelle à frequence mensuelle
    OUTPUT = série temporelle clean
    """

    print(f"\nCleaning...")

    #--> check continuité des années : stop_year = N si N < 12 mois, N-1 si "trou" entre N et N-1
    years= df_station["Year"].unique().tolist()
    years.sort(reverse=True)

    month_unique = []
    stop_year = 0

    for index, year in enumerate(years):
        df_station_year = df_station[df_station["Year"] == year]
        month_unique = df_station_year["Month"].unique().tolist()
        if len(month_unique)!=12:
            stop_year = year
            print(f"Année : {year}. Continuité rompue.")
            print(f"Mois: {len(month_unique)} / 12.")
            break
        else:
            try:
                if year - years[index+1] != 1:
                    stop_year = years[index+1]
                    print(f"Année : {years[index+1]}. Continuité rompue.")
                    print(f"Année manquante : {years[index+1]}")
                    break
            except IndexError:
                print("Continuité garantie")
                pass

    #--> drop
    if stop_year > 0:
        dataframe = dataframe[dataframe["Year"] > stop_year]

        print(f"Données antérieures à {stop_year+1} supprimées.")
    else:
        print(f"Aucune rupture de continuité constatée, toutes les données ont été conservées.")
    

    #--> transforme en série temporelle à frequence mensuelle
    dataframe.set_index("date", inplace=True)
    dataframe = dataframe.asfreq("ME")

    #--> check NA
    check = "NOT OK" if dataframe.isna().any().any() else "OK"
    print(f"Check valeurs manquantes : {check}")
    print(f"...Terminé.")

    return dataframe

# %%
def get_wind_forecast(time, data):

    """
    INPUT =  nombre de mois (time) à prédire et le set de données

    --> prédit la force du vent à horizon "time"
    
    OUTPUT =  le df initial en série temporelle + ajout d'une colonne "prédictions"
    """

    print(f"\nForecast à horizon {time} ans...")

    # split variables exogènes / target 
    to_keep = ["LON","LAT","ALTI"]

    var_exog_train = data[to_keep]
    y_train = data["vent_speed_inst_moy_mensu"]

    # construction var exog à prédire
    start_pred = var_exog_train.index[-1] + pd.DateOffset(months=1)
    end_pred = start_pred + pd.DateOffset(years=time) - pd.DateOffset(months=1)
    index_pred = pd.date_range(start=start_pred, end=end_pred, freq="ME")

    # les var exog sont constantes, le .max récupère juste la donnée
    var_exog_pred = pd.DataFrame({
    "LON": var_exog_train["LON"].max(),  
    "LAT": var_exog_train["LAT"].max(),   
    "ALTI": var_exog_train["ALTI"].max()
    }, index=index_pred)

    # training
    model = SARIMAX(y_train, exog=var_exog_train, order=(1, 1, 1), seasonal_order=(1, 1, 2, 12), enforce_stationarity=False)
    sarima_model = model.fit(maxiter=1000)

    # prédictions
    forecast = sarima_model.get_forecast(steps = time*12, exog = var_exog_pred)
    predicted_values = forecast.predicted_mean

    # rendu
    df_pred = var_exog_pred
    useless_col = ["vent_speed_inst_moy_mensu","Month","Year","LON","LAT","ALTI"] # LON,LAT,ALTI déja dans var_exog_pred, donc dans df_pred à ce stade
    remain_col = [col for col in data.columns if col not in useless_col]
    for col in remain_col:
        df_pred[col] = data[col].max()
    df_pred["pred"] = predicted_values
        
    print("...Terminé.")
    return df_pred

# %%
# créé un dictionnaire contenant un dataframe par numéro de station
# clean continuité des dates sur le dataframe + transforme en série temporelle (clean_continuity)
# prédit (get_wind_forecast) et enregistre les prédictions horizon

stations = df_recent["NUM_POSTE"].unique()
horizon = 7

dict_stations = {}

print("##################### START #####################")

for station in stations:
    print(f"\n\n ======> Station : [{station}] <======")
    df_station = df_recent[df_recent["NUM_POSTE"]==station]
    df_station = clean_continuity(df_station)
    dict_stations[station] = get_wind_forecast(horizon,df_station)

print("##################### END #####################")
# Out:
# ##################### START #####################
#
#
#  ======> Station : [1014002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [1071001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [1414001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [2037002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [2173002] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [2320001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [2321002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [3155003] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [3180001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [3185007] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [4019001] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [4096401] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [4134002] <======
#
# Cleaning...
# Année : 2008. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2009 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [4209005] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5046001] <======
#
# Cleaning...
# Année : 1957. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1958 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5055001] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5061009] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5070003] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5077402] <======
#
# Cleaning...
# Année : 2000. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2001 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5145002] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [5170001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [6005001] <======
#
# Cleaning...
# Année : 1987. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1988 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [6081001] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [6094002] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [8145001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [8401001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [9161003] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [10057001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [10228002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11069001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11076001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11081003] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11124003] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11168001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [11221004] <======
#
# Cleaning...
# Année : 1993. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1994 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [12154003] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [12216001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [12254001] <======
#
# Cleaning...
# Année : 1996. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 1997 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [12300004] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [14216001] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# c:\Users\alexm\anaconda3\envs\jedha_project\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...Terminé.
#
#
#  ======> Station : [15060002] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [15120005] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [15122002] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [16225001] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [17268002] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [18015003] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [18125004] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [18172003] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [18175003] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [19010001] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20041001] <======
#
# Cleaning...
# Année : 1950. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1951 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20093002] <======
#
# Cleaning...
# Année : 1988. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 1989 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20114002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20185003] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20223001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20232002] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20258001] <======
#
# Cleaning...
# Année : 1993. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1994 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20268001] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [20272004] <======
#
# Cleaning...
# Année : 1996. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1997 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [21065001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [21131001] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [21154001] <======
#
# Cleaning...
# Année : 1988. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1989 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [21561003] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [22219003] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [25219002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [25223002] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [25356003] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [25494001] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [25529002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [28070001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [28198001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [28206001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [28407001] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [30003001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [30101001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [30132004] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [30258001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [30352002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [31147001] <======
#
# Cleaning...
# Année : 1994. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1995 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [31406002] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [32315001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [33314005] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [34028003] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [34178001] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [34205001] <======
#
# Cleaning...
# Année : 1994. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1995 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [34209002] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [34239002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [35005001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [35110003] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [35202001] <======
#
# Cleaning...
# Année : 1988. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1989 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [36127002] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [36173002] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [37107001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [37192001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [37213003] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [37240001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [38187400] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [39097003] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [39413001] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [39485002] <======
#
# Cleaning...
# Année : 1996. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 1997 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [39526003] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [40087001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [40246003] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [41281001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [43111002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [44110002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [45055001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [46071001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [46100001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [46127001] <======
#
# Cleaning...
# Année : 1961. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1962 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [46181001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [46197002] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [48004001] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [48095005] <======
#
# Cleaning...
# Année : 2008. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2009 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [49188001] <======
#
# Cleaning...
# Année : 1999. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2000 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [51015001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [51237002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [51388003] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [51595002] <======
#
# Cleaning...
# Année : 2000. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2001 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [52055001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [52248002] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [54171001] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [54481001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [54582001] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [55386002] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [55484001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [55531001] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [56017003] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [56243001] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [57251001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [57587003] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [57644001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [57732001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [58062001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [58079004] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [58160001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [58218006] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [59534001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [59606004] <======
#
# Cleaning...
# Année : 2007. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2008 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [60322001] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [60555002] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [60566001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [60639001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [61006005] <======
#
# Cleaning...
# Année : 1994. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1995 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [62685001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [65125001] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [65460002] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [66136001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [66137003] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [66187006] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [66233001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [67029001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [67462004] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [67516001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [68062001] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [70132001] <======
#
# Cleaning...
# Année : 1997. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1998 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [70447002] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [70545001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [70561002] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [71014004] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [71081001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [71105001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [71320001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [71558001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [77054001] <======
#
# Cleaning...
# Année : 1991. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1992 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [77084001] <======
#
# Cleaning...
# Année : 1999. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2000 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [77211001] <======
#
# Cleaning...
# Année : 1992. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 1993 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [77306001] <======
#
# Cleaning...
# Année : 1953. Continuité rompue.
# Mois: 2 / 12.
# Données antérieures à 1954 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [77333003] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [78005002] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [78354001] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [79174002] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [79191005] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [79326004] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [80523001] <======
#
# Cleaning...
# Année : 2007. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2008 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [80682001] <======
#
# Cleaning...
# Année : 1993. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1994 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [81115002] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [81182004] <======
#
# Cleaning...
# Année : 1989. Continuité rompue.
# Mois: 9 / 12.
# Données antérieures à 1990 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [81192005] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [81217002] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [81292001] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [82038006] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [82094004] <======
#
# Cleaning...
# Année : 2002. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2003 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [85060002] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [85092004] <======
#
# Cleaning...
# Année : 1993. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1994 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [85169002] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [85182004] <======
#
# Cleaning...
# Année : 1993. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 1994 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [86027001] <======
#
# Cleaning...
# Continuité garantie
# Aucune rupture de continuité constatée, toutes les données ont été conservées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [86078002] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [86137003] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 11 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [86165005] <======
#
# Cleaning...
# Année : 1990. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 1991 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [87089003] <======
#
# Cleaning...
# Année : 1995. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 1996 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [87154003] <======
#
# Cleaning...
# Année : 1996. Continuité rompue.
# Mois: 6 / 12.
# Données antérieures à 1997 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [88271001] <======
#
# Cleaning...
# Année : 2001. Continuité rompue.
# Mois: 1 / 12.
# Données antérieures à 2002 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [88393003] <======
#
# Cleaning...
# Année : 2008. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2009 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [88402002] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 10 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [89333001] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 5 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [89365001] <======
#
# Cleaning...
# Année : 2005. Continuité rompue.
# Mois: 8 / 12.
# Données antérieures à 2006 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [89380001] <======
#
# Cleaning...
# Année : 2003. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2004 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [89387002] <======
#
# Cleaning...
# Année : 1986. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1987 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [89418007] <======
#
# Cleaning...
# Année : 2004. Continuité rompue.
# Mois: 4 / 12.
# Données antérieures à 2005 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [91184001] <======
#
# Cleaning...
# Année : 1998. Continuité rompue.
# Mois: 3 / 12.
# Données antérieures à 1999 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
#
#
#  ======> Station : [91200002] <======
#
# Cleaning...
# Année : 2006. Continuité rompue.
# Mois: 7 / 12.
# Données antérieures à 2007 supprimées.
# Check valeurs manquantes : OK
# ...Terminé.
#
# Forecast à horizon 7 ans...
# ...Terminé.
# ##################### END #####################

# %%
dict_stations[stations[0]]
# Out:
#               LON        LAT  ALTI  NUM_POSTE NOM_USUEL  departement_num  \
# 2023-01-31  5.669  46.278167   534    1014002    ARBENT                1
# 2023-02-28  5.669  46.278167   534    1014002    ARBENT                1
# 2023-03-31  5.669  46.278167   534    1014002    ARBENT                1
# 2023-04-30  5.669  46.278167   534    1014002    ARBENT                1
# 2023-05-31  5.669  46.278167   534    1014002    ARBENT                1
# ...           ...        ...   ...        ...       ...              ...
# 2029-08-31  5.669  46.278167   534    1014002    ARBENT                1
# 2029-09-30  5.669  46.278167   534    1014002    ARBENT                1
# 2029-10-31  5.669  46.278167   534    1014002    ARBENT                1
# 2029-11-30  5.669  46.278167   534    1014002    ARBENT                1
# 2029-12-31  5.669  46.278167   534    1014002    ARBENT                1
#
#            departement_name                region      pred
# 2023-01-31              Ain  AUVERGNE RHONE ALPES  6.131917
# 2023-02-28              Ain  AUVERGNE RHONE ALPES  6.731668
# 2023-03-31              Ain  AUVERGNE RHONE ALPES  6.977456
# 2023-04-30              Ain  AUVERGNE RHONE ALPES  7.293580
# 2023-05-31              Ain  AUVERGNE RHONE ALPES  7.372916
# ...                     ...                   ...       ...
# 2029-08-31              Ain  AUVERGNE RHONE ALPES  6.301794
# 2029-09-30              Ain  AUVERGNE RHONE ALPES  5.954180
# 2029-10-31              Ain  AUVERGNE RHONE ALPES  6.350162
# 2029-11-30              Ain  AUVERGNE RHONE ALPES  6.130554
# 2029-12-31              Ain  AUVERGNE RHONE ALPES  6.497901
#
# [84 rows x 9 columns]

# %%
df_stat = dict_stations[stations[0]].reset_index()

# %%
df_pred_total = pd.DataFrame(columns=df_stat.columns)
for key,value in dict_stations.items():
    df_stat = value.reset_index()
    df_pred_total = pd.concat([df_pred_total,df_stat], ignore_index=True)
# Out:
# C:\Users\alexm\AppData\Local\Temp\ipykernel_21436\4082424958.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_pred_total = pd.concat([df_pred_total,df_stat], ignore_index=True)

# %%
df_pred_total
# Out:
#            index    LON        LAT ALTI NUM_POSTE NOM_USUEL departement_num  \
# 0     2023-01-31  5.669  46.278167  534   1014002    ARBENT               1
# 1     2023-02-28  5.669  46.278167  534   1014002    ARBENT               1
# 2     2023-03-31  5.669  46.278167  534   1014002    ARBENT               1
# 3     2023-04-30  5.669  46.278167  534   1014002    ARBENT               1
# 4     2023-05-31  5.669  46.278167  534   1014002    ARBENT               1
# ...          ...    ...        ...  ...       ...       ...             ...
# 17047 2029-08-31  1.993  48.526167  116  91200002   DOURDAN              91
# 17048 2029-09-30  1.993  48.526167  116  91200002   DOURDAN              91
# 17049 2029-10-31  1.993  48.526167  116  91200002   DOURDAN              91
# 17050 2029-11-30  1.993  48.526167  116  91200002   DOURDAN              91
# 17051 2029-12-31  1.993  48.526167  116  91200002   DOURDAN              91
#
#       departement_name                region      pred
# 0                  Ain  AUVERGNE RHONE ALPES  6.131917
# 1                  Ain  AUVERGNE RHONE ALPES  6.731668
# 2                  Ain  AUVERGNE RHONE ALPES  6.977456
# 3                  Ain  AUVERGNE RHONE ALPES  7.293580
# 4                  Ain  AUVERGNE RHONE ALPES  7.372916
# ...                ...                   ...       ...
# 17047          Essonne         ILE DE FRANCE  6.451926
# 17048          Essonne         ILE DE FRANCE  6.531559
# 17049          Essonne         ILE DE FRANCE  6.585855
# 17050          Essonne         ILE DE FRANCE  7.408695
# 17051          Essonne         ILE DE FRANCE  8.260177
#
# [17052 rows x 10 columns]

# %%
# rajouter moyenne force de vent par station

# %%
df_pred_total.to_csv(f"pred_horizon_{horizon}_ans.csv", index=False)
